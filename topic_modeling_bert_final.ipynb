# %% [markdown]
# Basic tutorial - https://colab.research.google.com/drive/1FieRA9fLdkQEGDIMYl0I3MCjSUKVF8C-?usp=sharing#scrollTo=S9qDqEHddgKq
#
# Best practices - https://colab.research.google.com/drive/1BoQ_vakEVtojsd2x_U6-_x52OOuqruj2?usp=sharing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys

folder_path = '/content/drive/MyDrive/Nova IMS/Text Mining/Project'
sys.path.append(folder_path)

# %%
import time
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import emoji
import Preprocessing_topicM as preproc
import nltk
import warnings
warnings.filterwarnings("ignore")

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
reviews_raw = pd.read_csv(r"data_hyderabad\10k_reviews.csv")

# %%
reviews_data = reviews_raw[reviews_raw["Rating"].notna() & reviews_raw["Review"].notna()]
reviews_data.isna().sum()
# Out:
# Restaurant    0
# Reviewer      0
# Review        0
# Rating        0
# Metadata      0
# Time          0
# Pictures      0
# dtype: int64

# %%
# split UPPERCASE WORDS
def splitting_words_process(word):
    # only upper case letters
    if word.isupper():
        return word

    # more than one upper case letter inside
    elif re.search(r'[A-Z][a-z]*[A-Z]', word):
        split_word = re.findall(r'[A-Z][a-z]*', word)
        return ' '.join(split_word)

    # <2 upper case letters
    else:
        return word

reviews_data['Review'] = reviews_data['Review'].apply(lambda x: ' '.join([splitting_words_process(word) for word in x.split()]))

# %%
# Function to replace 'gud', 'goo', 'gd' with the appropriate 'good'
def replace_gud_with_good(text):
    if isinstance(text, str):
        # Define the regex pattern to match 'gud', 'goo', 'gd' in various capitalizations
        pattern = re.compile(r'\b([Gg][Uu][Dd]|[Gg][Oo][Oo]|[Gg][Dd])\b')

        # Replacement function to check the case of the first letter
        def replacement(match):
            word = match.group()
            # Check if the first letter is uppercase, then return 'Good', else 'good'
            if word[0].isupper():
                return 'Good'
            else:
                return 'good'

        # Use re.sub to apply the replacement function
        return pattern.sub(replacement, text)

    return text

# Apply the function to the 'Review' column to replace the variants of 'good'
reviews_data['Review'] = reviews_data['Review'].apply(replace_gud_with_good)

# %%
# Function to replace 'kk', 'Oke', 'k', 'Ok' with 'ok'
def replace_to_ok(text):
    if isinstance(text, str):
        # Define the regex pattern to match the variants of 'ok'
        pattern = re.compile(r'\b(k|kk|Ok|Oke)\b', re.IGNORECASE)

        # Replacement function to return 'ok' for all matched words
        def replacement(match):
            return 'ok'

        # Use re.sub to apply the replacement function
        return pattern.sub(replacement, text)

    return text

# Apply the function to the 'Review' column to replace the variants of 'ok'
reviews_data['Review'] = reviews_data['Review'].apply(replace_to_ok)

# %%
# add space after ! | " | # | $ | % | & | ( | ) | * | + | , | . | : | ; followed immediately by a word
def add_space_after_punctuation(df):

    df['Review'] = df['Review'].apply(lambda text: re.sub(r'([\u0021-\u0026\u0028-\u002C\u002E\u003A-\u003F]+(?=\w))', r'\1 ', text) if isinstance(text, str) else text)
    return df

# Example usage:
reviews_data = add_space_after_punctuation(reviews_data)

# %%
# remove gibberish words like "ggggggggggd", "eshjdgue"
def remove_gibberish(text):
    cleaned_text = re.sub(r'\b\w{15,}\b', '', text)  # removes 15+ words
    cleaned_text = re.sub(r'\b\w*(\w)\1{2,}\w*\b', '', cleaned_text)  # removes words that contain 3+ repeating letters

    return cleaned_text

reviews_data['Review'] = reviews_data['Review'].apply(remove_gibberish)

# %%
def remove_space_before_punctuation(text):
    if isinstance(text, str):
        # Define the regex pattern to match spaces before punctuation
        pattern = re.compile(r'\s+([?.!,;:])')

        # Use re.sub to remove spaces before punctuation
        return pattern.sub(r'\1', text)

    return text

# Apply the function to the 'Review' column to remove spaces before punctuation
reviews_data['Review'] = reviews_data['Review'].apply(remove_space_before_punctuation)

# %%
reviews_preproc = reviews_data['Review'].apply(lambda x: preproc.main_pipeline(
    x,
    print_output=False,
    no_stopwords=False,
    custom_stopwords=[],
    convert_diacritics=True,
    no_punctuation=False,
    remove_contractions = True,
    lowercase=False,
    lemmatized=False,
    stemmed=False,
    tokenized_output=False
))

# %%
def remove_space_before_punctuation(text):
    if isinstance(text, str):
        # Define the regex pattern to match spaces before punctuation
        pattern = re.compile(r'\s+([?.!,;:])')

        # Use re.sub to remove spaces before punctuation
        return pattern.sub(r'\1', text)

    return text

# Apply the function to the 'Review' column to remove spaces before punctuation
reviews_preproc = reviews_preproc.apply(remove_space_before_punctuation)

# %%
reviews_preproc = reviews_preproc[reviews_preproc.apply(lambda x: len(x) >= 3 if isinstance(x, str) else False)]

# %%
len(reviews_preproc)
# Out:
# 9910

# %%
print(reviews_preproc)
# Out:
# 0       The ambience was good, food was quite good. ha...
# 1       Ambience is too good for a pleasant evening. S...
# 2       A must try.. great food great ambience. Thnx f...
# 3       Soumen das and Arun was a great guy. Only beca...
# 4       Food is good. we ordered Kodi drumsticks and b...
#                               ...
# 9995    Madhumathi Mahajan Well to start with nice cou...
# 9996    This place has never disappointed us.. The foo...
# 9997    Bad rating is mainly because of "Chicken Bone ...
# 9998    I personally love and prefer Chinese Food. Had...
# 9999    Checked in here to try some delicious chinese ...
# Name: Review, Length: 9910, dtype: object

# %%
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance, PartOfSpeech
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from umap import UMAP
from hdbscan import HDBSCAN

# %%
from sentence_transformers import SentenceTransformer

# Pre-calculate embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = embedding_model.encode(reviews_preproc.tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/310 [00:00<?, ?it/s]

# %%
vectorizer_model = CountVectorizer(stop_words="english", ngram_range=(1, 1))
ctfidf_model = ClassTfidfTransformer()
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine')
hdbscan_model = HDBSCAN(min_cluster_size=50,metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# %%
model_base = BERTopic(
    language="english",
    calculate_probabilities=True,
    embedding_model= embedding_model,
    vectorizer_model=vectorizer_model,
    ctfidf_model=ctfidf_model,
    umap_model= umap_model,
    hdbscan_model=hdbscan_model,
    representation_model={"MMR": MaximalMarginalRelevance(diversity=0.3),
                          "KeyBert": KeyBERTInspired(),
                          "Pos": PartOfSpeech()},
    verbose = True
)
topics_base, probs_base = model_base.fit_transform(reviews_preproc,embeddings)
# Out:
# 2024-12-15 21:45:02,068 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-12-15 21:45:20,810 - BERTopic - Dimensionality - Completed ✓
# 2024-12-15 21:45:20,811 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-12-15 21:45:21,614 - BERTopic - Cluster - Completed ✓
# 2024-12-15 21:45:21,619 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-12-15 21:45:25,080 - BERTopic - Representation - Completed ✓

# %%
model_base.get_topic_info()
# Out:
#    Topic  Count                           Name  \
# 0     -1    121  -1_nice_super_awesome_sonalin
# 1      0   8925      0_food_good_place_service
# 2      1    335      1_delivery_time_fast_good
# 3      2    307      2_good_bhehave_verry_nice
# 4      3     91   3_excellent_good_nice_awsome
# 5      4     73    4_service_good_superb_thank
# 6      5     58   5_momos_momo_kurkure_steamed
#
#                                       Representation  \
# 0  [nice, super, awesome, sonalin, voice, job, te...
# 1  [food, good, place, service, chicken, taste, o...
# 2  [delivery, time, fast, good, delivered, late, ...
# 3           [good, bhehave, verry, nice, , , , , , ]
# 4  [excellent, good, nice, awsome, boy, great, th...
# 5  [service, good, superb, thank, nice, thanks, e...
# 6  [momos, momo, kurkure, steamed, chicken, fried...
#
#                                                  MMR  \
# 0  [awesome, sonalin, voice, singer, priyadarshin...
# 1  [food, chicken, ambience, biryani, restaurant,...
# 2  [delivery, delivered, super, deliver, man, ser...
# 3  [good, bhehave, verry, nice, , , , , , , , , ,...
# 4  [excellent, awsome, thank, rider, amazing, guy...
# 5  [service, superb, sarvic, rehman, customer, pr...
# 6  [momos, kurkure, steamed, chicken, mayo, mayon...
#
#                                              KeyBert  \
# 0  [nice, awesome, great, cool, good, excellent, ...
# 1  [restaurant, buffet, food, dishes, lunch, dinn...
# 2  [delivery, deliver, delivered, timely, delay, ...
# 3                       [good, nice, , , , , , , , ]
# 4  [excellent, great, good, amazing, nice, perfec...
# 5  [service, services, served, customer, best, ex...
# 6  [momos, momo, steamed, kurkure, tasty, kukure,...
#
#                                                  Pos  \
# 0  [nice, super, awesome, voice, job, test, singe...
# 1  [food, good, place, service, chicken, taste, a...
# 2  [delivery, time, fast, good, late, boy, quick,...
# 3                       [good, nice, , , , , , , , ]
# 4  [excellent, good, nice, boy, great, rider, guy...
# 5  [service, good, superb, nice, thanks, excellen...
# 6  [momos, momo, kurkure, steamed, chicken, fried...
#
#                                  Representative_Docs
# 0                                 [nice, nice, Nice]
# 1  [Good place to dine with family and friends. T...
# 2  [Delivery is Good on Time, Good delivery time,...
# 3                                 [Good, good, good]
# 4                  [excellent, excellent, excellent]
# 5  [good service keep it up, very good service, v...
# 6  [Big fan of kurkure chicken momos served here....

# %%
# Create a DataFrame with reviews and their top 3 assigned topics with probabilities
reviews_with_topics = pd.DataFrame({
    'Review': reviews_preproc,
    'Top_3_Topics': [np.argsort(probs_base[i])[-3:][::-1] for i in range(len(reviews_preproc))],
    'Top_3_Probabilities': [np.round(np.sort(probs_base[i])[-3:][::-1] * 100, 2) for i in range(len(reviews_preproc))]
})

# Map the topic IDs to their custom names from topic_aspects_["MMR"]
topic_info_MMR = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_base.topic_aspects_["MMR"].items()}
topic_info_KB = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_base.topic_aspects_["KeyBert"].items()}
topic_info_POS = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_base.topic_aspects_["Pos"].items()}
reviews_with_topics['Topics_MMR'] = reviews_with_topics['Top_3_Topics'].apply(lambda topics: [topic_info_MMR[topic] for topic in topics])
reviews_with_topics['Topics_KB'] = reviews_with_topics['Top_3_Topics'].apply(lambda topics: [topic_info_KB[topic] for topic in topics])
reviews_with_topics['Topics_POS'] = reviews_with_topics['Top_3_Topics'].apply(lambda topics: [topic_info_POS[topic] for topic in topics])

# Display the first few rows of the new DataFrame
reviews_with_topics
# Out:
#                                                  Review Top_3_Topics  \
# 0     The ambience was good, food was quite good. ha...    [0, 5, 1]
# 1     Ambience is too good for a pleasant evening. S...    [0, 5, 1]
# 2     A must try.. great food great ambience. Thnx f...    [0, 5, 1]
# 3     Soumen das and Arun was a great guy. Only beca...    [0, 5, 1]
# 4     Food is good. we ordered Kodi drumsticks and b...    [0, 5, 1]
# ...                                                 ...          ...
# 9995  Madhumathi Mahajan Well to start with nice cou...    [0, 5, 1]
# 9996  This place has never disappointed us.. The foo...    [0, 5, 1]
# 9997  Bad rating is mainly because of "Chicken Bone ...    [0, 5, 1]
# 9998  I personally love and prefer Chinese Food. Had...    [0, 5, 1]
# 9999  Checked in here to try some delicious chinese ...    [0, 5, 1]
#
#        Top_3_Probabilities                                         Topics_MMR  \
# 0        [79.72, 7.0, 4.7]  [food | chicken | ambience, momos | kurkure | ...
# 1        [100.0, 0.0, 0.0]  [food | chicken | ambience, momos | kurkure | ...
# 2        [89.3, 3.58, 2.5]  [food | chicken | ambience, momos | kurkure | ...
# 3      [94.65, 1.89, 1.21]  [food | chicken | ambience, momos | kurkure | ...
# 4      [78.44, 8.28, 4.69]  [food | chicken | ambience, momos | kurkure | ...
# ...                    ...                                                ...
# 9995   [97.41, 1.12, 0.51]  [food | chicken | ambience, momos | kurkure | ...
# 9996     [100.0, 0.0, 0.0]  [food | chicken | ambience, momos | kurkure | ...
# 9997  [78.72, 10.44, 3.74]  [food | chicken | ambience, momos | kurkure | ...
# 9998     [100.0, 0.0, 0.0]  [food | chicken | ambience, momos | kurkure | ...
# 9999    [90.43, 4.7, 1.67]  [food | chicken | ambience, momos | kurkure | ...
#
#                                               Topics_KB  \
# 0     [restaurant | buffet | food, momos | momo | st...
# 1     [restaurant | buffet | food, momos | momo | st...
# 2     [restaurant | buffet | food, momos | momo | st...
# 3     [restaurant | buffet | food, momos | momo | st...
# 4     [restaurant | buffet | food, momos | momo | st...
# ...                                                 ...
# 9995  [restaurant | buffet | food, momos | momo | st...
# 9996  [restaurant | buffet | food, momos | momo | st...
# 9997  [restaurant | buffet | food, momos | momo | st...
# 9998  [restaurant | buffet | food, momos | momo | st...
# 9999  [restaurant | buffet | food, momos | momo | st...
#
#                                              Topics_POS
# 0     [food | good | place, momos | momo | kurkure, ...
# 1     [food | good | place, momos | momo | kurkure, ...
# 2     [food | good | place, momos | momo | kurkure, ...
# 3     [food | good | place, momos | momo | kurkure, ...
# 4     [food | good | place, momos | momo | kurkure, ...
# ...                                                 ...
# 9995  [food | good | place, momos | momo | kurkure, ...
# 9996  [food | good | place, momos | momo | kurkure, ...
# 9997  [food | good | place, momos | momo | kurkure, ...
# 9998  [food | good | place, momos | momo | kurkure, ...
# 9999  [food | good | place, momos | momo | kurkure, ...
#
# [9910 rows x 6 columns]

# %%
hierarchical_topics = model_base.hierarchical_topics(reviews_preproc)
# Out:
# 100%|██████████| 52/52 [00:00<00:00, 257.71it/s]

# %%
model_base.visualize_hierarchy(hierarchical_topics=hierarchical_topics)

# %%
len(model_base.get_topics())
# Out:
# 54

# %%
model_reduced = model_base.reduce_topics(reviews_preproc, nr_topics=10)
# Out:
# 2024-12-15 21:38:16,524 - BERTopic - Topic reduction - Reducing number of topics
# 2024-12-15 21:38:20,638 - BERTopic - Topic reduction - Reduced number of topics from 54 to 10

# %%
topics_reduced = model_reduced.topics_
probs_reduced = model_reduced.probabilities_

# %%
# Create a DataFrame with reviews and their top 3 assigned topics with probabilities
reviews_with_topics_merged = pd.DataFrame({
    'Review': reviews_preproc,
    'Top_3_Topics': [np.argsort(probs_reduced[i])[-3:][::-1] for i in range(len(reviews_preproc))],
    'Top_3_Probabilities': [np.round(np.sort(probs_reduced[i])[-3:][::-1] * 100, 2) for i in range(len(reviews_preproc))]
})

# Map the topic IDs to their custom names from topic_aspects_["MMR"]
topic_info_MMR_merged = {topic: " | ".join(list(zip(*values))[0][:1]) for topic, values in model_reduced.topic_aspects_["MMR"].items()}
topic_info_KB_merged = {topic: " | ".join(list(zip(*values))[0][:1]) for topic, values in model_reduced.topic_aspects_["KeyBert"].items()}
topic_info_POS_merged = {topic: " | ".join(list(zip(*values))[0][:1]) for topic, values in model_reduced.topic_aspects_["Pos"].items()}
reviews_with_topics_merged['Topics_MMR'] = reviews_with_topics_merged['Top_3_Topics'].apply(lambda topics: [topic_info_MMR_merged[topic] for topic in topics])
reviews_with_topics_merged['Topics_KB'] = reviews_with_topics_merged['Top_3_Topics'].apply(lambda topics: [topic_info_KB_merged[topic] for topic in topics])
reviews_with_topics_merged['Topics_POS'] = reviews_with_topics_merged['Top_3_Topics'].apply(lambda topics: [topic_info_POS_merged[topic] for topic in topics])

# Display the first few rows of the new DataFrame
reviews_with_topics_merged
# Out:
#                                                  Review Top_3_Topics  \
# 0     The ambience was good, food was quite good. ha...    [0, 2, 4]
# 1     Ambience is too good for a pleasant evening. S...    [0, 2, 4]
# 2     A must try.. great food great ambience. Thnx f...    [0, 2, 4]
# 3     Soumen das and Arun was a great guy. Only beca...    [0, 2, 7]
# 4     Food is good. we ordered Kodi drumsticks and b...    [0, 2, 4]
# ...                                                 ...          ...
# 9995  Madhumathi Mahajan Well to start with nice cou...    [0, 2, 4]
# 9996  This place has never disappointed us.. The foo...    [0, 2, 4]
# 9997  Bad rating is mainly because of "Chicken Bone ...    [0, 2, 4]
# 9998  I personally love and prefer Chinese Food. Had...    [0, 2, 4]
# 9999  Checked in here to try some delicious chinese ...    [0, 2, 4]
#
#       Top_3_Probabilities                   Topics_MMR  \
# 0      [58.83, 5.82, 2.5]     [food, chocolate, spicy]
# 1     [77.88, 3.42, 1.36]     [food, chocolate, spicy]
# 2     [59.79, 5.87, 2.14]     [food, chocolate, spicy]
# 3       [81.65, 3.0, 1.4]  [food, chocolate, sizzlers]
# 4     [15.72, 1.45, 0.73]     [food, chocolate, spicy]
# ...                   ...                          ...
# 9995    [100.0, 0.0, 0.0]     [food, chocolate, spicy]
# 9996   [46.7, 2.23, 1.52]     [food, chocolate, spicy]
# 9997  [20.43, 1.44, 1.09]     [food, chocolate, spicy]
# 9998    [100.0, 0.0, 0.0]     [food, chocolate, spicy]
# 9999  [36.82, 2.39, 1.71]     [food, chocolate, spicy]
#
#                              Topics_KB              Topics_POS
# 0        [restaurant, icecream, spicy]     [food, cake, spicy]
# 1        [restaurant, icecream, spicy]     [food, cake, spicy]
# 2        [restaurant, icecream, spicy]     [food, cake, spicy]
# 3     [restaurant, icecream, sizzlers]  [food, cake, sizzlers]
# 4        [restaurant, icecream, spicy]     [food, cake, spicy]
# ...                                ...                     ...
# 9995     [restaurant, icecream, spicy]     [food, cake, spicy]
# 9996     [restaurant, icecream, spicy]     [food, cake, spicy]
# 9997     [restaurant, icecream, spicy]     [food, cake, spicy]
# 9998     [restaurant, icecream, spicy]     [food, cake, spicy]
# 9999     [restaurant, icecream, spicy]     [food, cake, spicy]
#
# [9910 rows x 6 columns]

# %%
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance, PartOfSpeech

# Set the random seed for reproducibility
random_seed = 42

# Initialize the UMAP model with a random seed
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine', random_state=random_seed)

# Initialize the HDBSCAN model with a random seed
hdbscan_model = HDBSCAN(min_cluster_size=30, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# Initialize the BERTopic model with the random seed
model_custom_merged = BERTopic(
    language="english",
    calculate_probabilities=True,
    embedding_model=embedding_model,
    vectorizer_model=vectorizer_model,
    ctfidf_model=ctfidf_model,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    representation_model={
        "MMR": MaximalMarginalRelevance(diversity=0.3),
        "KeyBert": KeyBERTInspired(),
        "Pos": PartOfSpeech()
    },
    verbose=True,
)

# Fit the model and transform the data
topics_custom, probs_custom = model_custom_merged.fit_transform(reviews_preproc, embeddings)
# Out:
# 2024-12-15 21:38:44,946 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-12-15 21:39:01,401 - BERTopic - Dimensionality - Completed ✓
# 2024-12-15 21:39:01,403 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-12-15 21:39:02,998 - BERTopic - Cluster - Completed ✓
# 2024-12-15 21:39:03,004 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-12-15 21:39:24,301 - BERTopic - Representation - Completed ✓

# %%
hierarchical_topics = model_custom_merged.hierarchical_topics(reviews_preproc)
# Out:
# 100%|██████████| 52/52 [00:00<00:00, 212.98it/s]

# %%
model_custom_merged.visualize_hierarchy(hierarchical_topics=hierarchical_topics)

# %%
model_custom_merged.merge_topics(reviews_preproc, topics_to_merge=[[41,42,2],[53,3],[29,2,7],[32,17,47],[34,37],[53,3],[4,10],[25,22,28,26]])

# %%
len(model_custom_merged.get_topic_info())
# Out:
# 44

# %%
model_custom_merged.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="03632dcf-c790-46e4-85ee-c5448578342f" class="plotly-graph-div" style="height:845px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03632dcf-c790-46e4-85ee-c5448578342f")) {                    Plotly.newPlot(                        "03632dcf-c790-46e4-85ee-c5448578342f",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["cake_cakes_chocolate_brownies_cupcakes","","","pasta_pizza_cheese_ravioli_italian"],"x":[0.0,0.6788504225513489,0.6788504225513489,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["cake_cakes_chocolate_brownies_cupcakes","","","coffee_cafe_bikes_cars_bike"],"x":[0.6788504225513489,0.8053609810612986,0.8053609810612986,0.0],"xaxis":"x","y":[-20.0,-20.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["chai_irani_karachi_cafe_old","","","coffee_cafe_bikes_cars_bike"],"x":[0.0,0.8398078618887576,0.8398078618887576,0.8053609810612986],"xaxis":"x","y":[-5.0,-5.0,-27.5,-27.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["ice_cream_creams_stone_nuts","","","shake_shakes_tempteys_brownie_caramel"],"x":[0.0,0.8230437231988204,0.8230437231988204,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["ice_cream_creams_stone_nuts","","","shake_shakes_tempteys_brownie_caramel"],"x":[0.8398078618887576,0.9712312820028095,0.9712312820028095,0.8230437231988204],"xaxis":"x","y":[-16.25,-16.25,-50.0,-50.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["burger_burgers_galaxy_chicken_milky","","","wings_wild_sauces_chicken_nuggets"],"x":[0.0,0.7084487321619064,0.7084487321619064,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["donuts_donut_dunkin_chocolate_burger","","","wings_wild_sauces_chicken_nuggets"],"x":[0.0,0.8697512068528109,0.8697512068528109,0.7084487321619064],"xaxis":"x","y":[-65.0,-65.0,-80.0,-80.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["spicy____uncooked_super_stomach","","","momos_kurkure_momo_steamed_sauce"],"x":[0.0,0.946354133263643,0.946354133263643,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["haleem_pista_house_ramzan_ghouse","","","mandi_yum_arabian_tree_chicken"],"x":[0.0,0.8859143629417684,0.8859143629417684,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["haleem_pista_house_ramzan_ghouse","","","sizzlers_sizzler_absolute_sizzling_dine"],"x":[0.8859143629417684,0.9497166941008812,0.9497166941008812,0.0],"xaxis":"x","y":[-120.0,-120.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["haleem_pista_house_ramzan_ghouse","","","sizzlers_sizzler_absolute_sizzling_dine"],"x":[0.946354133263643,0.9840097454940536,0.9840097454940536,0.9497166941008812],"xaxis":"x","y":[-100.0,-100.0,-127.5,-127.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["chicken_cooked_bad_smell_worst","","","shawarma_maggi_rumali_chicken_shah"],"x":[0.0,0.7591127821271969,0.759112782 ...

# %%
model_custom_merged.merge_topics(reviews_preproc, topics_to_merge=[[25,11,4], [26,8],[18,16],[38,6],[0,41]])

# %%
len(model_custom_merged.get_topic_info())
# Out:
# 38

# %%
model_custom_merged.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e604cb9d-c5cf-4ad7-8ac1-6aef79298e45" class="plotly-graph-div" style="height:755px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e604cb9d-c5cf-4ad7-8ac1-6aef79298e45")) {                    Plotly.newPlot(                        "e604cb9d-c5cf-4ad7-8ac1-6aef79298e45",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["noodles_manchurian_rice_fried_ordered","","","chinese_noodles_fried_rice_authentic"],"x":[0.0,0.5305289355330456,0.5305289355330456,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["buffet_spread_lunch_starters_veg","","","chicken_fish_soup_veg_paneer"],"x":[0.0,0.48343446940285917,0.48343446940285917,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","chicken_fish_soup_veg_paneer"],"x":[0.0,0.51621557632535,0.51621557632535,0.48343446940285917],"xaxis":"x","y":[-25.0,-25.0,-40.0,-40.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["hyderabad_gachibowli_place_best_food","","","place_ambience_music_dj_dance"],"x":[0.0,0.3594668730610746,0.3594668730610746,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["hyderabad_gachibowli_place_best_food","","","manager_service_asked_table_worst"],"x":[0.3594668730610746,0.5488780777865138,0.5488780777865138,0.0],"xaxis":"x","y":[-60.0,-60.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["hyderabad_gachibowli_place_best_food","","","manager_service_asked_table_worst"],"x":[0.51621557632535,0.687593378838207,0.687593378838207,0.5488780777865138],"xaxis":"x","y":[-32.5,-32.5,-67.5,-67.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["biryani_chicken_taste_ordered_biriyani","","","punjabi_paneer_paratha_indian_north"],"x":[0.0,0.6516244209351691,0.6516244209351691,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["biryani_chicken_taste_ordered_biriyani","","","punjabi_paneer_paratha_indian_north"],"x":[0.687593378838207,0.731336455975763,0.731336455975763,0.6516244209351691],"xaxis":"x","y":[-50.0,-50.0,-90.0,-90.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["biryani_chicken_taste_ordered_biriyani","","","punjabi_paneer_paratha_indian_north"],"x":[0.5305289355330456,0.9026469833489517,0.9026469833489517,0.731336455975763],"xaxis":"x","y":[-10.0,-10.0,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["delivery_fast_order_time_boy","","","zomato_gold_order_restaurant_support"],"x":[0.0,0.7980097624591422,0.7980097624591422,0.0],"xaxis":"x","y":[-105.0,-105.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["shawarma_maggi_rumali_chicken_shah","","","chicken_cooked_bad_smell_worst"],"x":[0.0,0.7507209261986892,0.7507209261986892,0.0],"xaxis":"x","y":[-135.0,-135.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["quantity_quality_food_price_taste","","","taste_waste_bad_zero_online"],"x":[0.0,0.7919086480449349,0.7919 ...

# %%
model_custom_merged.merge_topics(reviews_preproc, topics_to_merge=[[20,27],[7,26,16], [12,15],[24,36,31,27,32],[8,23]])

# %%
len(model_custom_merged.get_topic_info())
# Out:
# 30

# %%
model_custom_merged.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5bed595b-a7eb-456d-b35b-6bf8ae23f88c" class="plotly-graph-div" style="height:635px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bed595b-a7eb-456d-b35b-6bf8ae23f88c")) {                    Plotly.newPlot(                        "5bed595b-a7eb-456d-b35b-6bf8ae23f88c",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["chinese_noodles_rice_fried_manchurian","","","biryani_chicken_taste_ordered_mutton"],"x":[0.0,0.6196837946611209,0.6196837946611209,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["paneer_punjabi_paratha_indian_north","","","biryani_chicken_taste_ordered_mutton"],"x":[0.0,0.6528276816653943,0.6528276816653943,0.6196837946611209],"xaxis":"x","y":[-15.0,-15.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["chicken_fish_soup_veg_taste","","","buffet_spread_lunch_starters_veg"],"x":[0.0,0.4753461652715253,0.4753461652715253,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["chicken_fish_soup_veg_taste","","","veg_vegetarian_non_vegetarians_good"],"x":[0.4753461652715253,0.5043426171483447,0.5043426171483447,0.0],"xaxis":"x","y":[-50.0,-50.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["chicken_fish_soup_veg_taste","","","veg_vegetarian_non_vegetarians_good"],"x":[0.6528276816653943,0.6896803744029646,0.6896803744029646,0.5043426171483447],"xaxis":"x","y":[-22.5,-22.5,-57.5,-57.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["hyderabad_gachibowli_place_best_food","","","place_ambience_music_good_dj"],"x":[0.0,0.3479359630937602,0.3479359630937602,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["hyderabad_gachibowli_place_best_food","","","service_manager_asked_table_food"],"x":[0.3479359630937602,0.5386493879192934,0.5386493879192934,0.0],"xaxis":"x","y":[-90.0,-90.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["pizza_pasta_cheese_ravioli_italian","","","service_manager_asked_table_food"],"x":[0.0,0.6617773769290719,0.6617773769290719,0.5386493879192934],"xaxis":"x","y":[-75.0,-75.0,-97.5,-97.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["pizza_pasta_cheese_ravioli_italian","","","excellent_service_good_food_nice"],"x":[0.6617773769290719,0.6983873372622903,0.6983873372622903,0.0],"xaxis":"x","y":[-86.25,-86.25,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["pizza_pasta_cheese_ravioli_italian","","","excellent_service_good_food_nice"],"x":[0.6896803744029646,0.8050177461125361,0.8050177461125361,0.6983873372622903],"xaxis":"x","y":[-40.0,-40.0,-100.625,-100.625],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["mandi_yum_arabian_chicken_tree","","","excellent_service_good_food_nice"],"x":[0.0,0.8961156934739507,0.8961156934739507,0.8050177461125361],"xaxis":"x","y":[-5.0,-5.0,-70.3125,-70.3125],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["super_test_good_bad_yfjgz","","","good_nice_boy_rider_bhehave"],"x":[0.0,0.7781245 ...

# %%
model_custom_merged.merge_topics(reviews_preproc, topics_to_merge=[[3,2], [4,8],[12,14]])

# %%
model_custom_merged.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8ed120db-02e5-44e1-9e6b-2fe465360180" class="plotly-graph-div" style="height:590px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ed120db-02e5-44e1-9e6b-2fe465360180")) {                    Plotly.newPlot(                        "8ed120db-02e5-44e1-9e6b-2fe465360180",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["hyderabad_gachibowli_place_best_food","","","place_ambience_music_good_dj"],"x":[0.0,0.3428311136554212,0.3428311136554212,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["hyderabad_gachibowli_place_best_food","","","service_food_staff_manager_experience"],"x":[0.3428311136554212,0.46791206310379563,0.46791206310379563,0.0],"xaxis":"x","y":[-30.0,-30.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["pizza_pasta_cheese_ravioli_italian","","","service_food_staff_manager_experience"],"x":[0.0,0.6511564898400984,0.6511564898400984,0.46791206310379563],"xaxis":"x","y":[-15.0,-15.0,-37.5,-37.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","buffet_chicken_fish_veg_starters"],"x":[0.0,0.4293253523543916,0.4293253523543916,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","chinese_noodles_rice_fried_manchurian"],"x":[0.4293253523543916,0.5964944348941534,0.5964944348941534,0.0],"xaxis":"x","y":[-60.0,-60.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","biryani_chicken_taste_ordered_good"],"x":[0.5964944348941534,0.6291471360781216,0.6291471360781216,0.0],"xaxis":"x","y":[-67.5,-67.5,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","paneer_punjabi_paratha_indian_north"],"x":[0.6291471360781216,0.6447712341481641,0.6447712341481641,0.0],"xaxis":"x","y":[-76.25,-76.25,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","paneer_punjabi_paratha_indian_north"],"x":[0.6511564898400984,0.7467733154354718,0.7467733154354718,0.6447712341481641],"xaxis":"x","y":[-26.25,-26.25,-85.625,-85.625],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["mandi_yum_chicken_arabian_tree","","","paneer_punjabi_paratha_indian_north"],"x":[0.0,0.8879052759144307,0.8879052759144307,0.7467733154354718],"xaxis":"x","y":[-5.0,-5.0,-55.9375,-55.9375],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["momos_haleem_wrap_sizzlers_coffee","","","cake_cakes_chocolate_brownies_cupcakes"],"x":[0.0,0.7171616713948612,0.7171616713948612,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["momos_haleem_wrap_sizzlers_coffee","","","chai_irani_cafe_karachi_old"],"x":[0.7171616713948612,0.8241947959682993,0.8241947959682993,0.0],"xaxis":"x","y":[-120.0,-120.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["pancakes_waffle_tea_waffles_nutella","","","chai_irani_cafe ...

# %%
topics_custom = model_custom_merged.topics_
probs_custom = model_custom_merged.probabilities_

# %%
# Create a DataFrame with reviews and their top 3 assigned topics with probabilities
reviews_with_topics_custom = pd.DataFrame({
    'Review': reviews_preproc,
    'Top_3_Topics': [np.argsort(probs_custom[i])[-3:][::-1] for i in range(len(reviews_preproc))],
    'Top_3_Probabilities': [np.round(np.sort(probs_custom[i])[-3:][::-1] * 100, 2) for i in range(len(reviews_preproc))]
})

# Map the topic IDs to their custom names from topic_aspects_["MMR"]
topic_info_MMR_custom = {topic: " | ".join(list(zip(*values))[0][:1]) for topic, values in model_custom_merged.topic_aspects_["MMR"].items()}
topic_info_KB_custom = {topic: " | ".join(list(zip(*values))[0][:1]) for topic, values in model_custom_merged.topic_aspects_["KeyBert"].items()}
topic_info_POS_custom = {topic: " | ".join(list(zip(*values))[0][:1]) for topic, values in model_custom_merged.topic_aspects_["Pos"].items()}
reviews_with_topics_custom['Topics_MMR'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_MMR_custom[topic] for topic in topics])
reviews_with_topics_custom['Topics_KB'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_KB_custom[topic] for topic in topics])
#reviews_with_topics_custom['Topics_POS'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_POS_custom[topic] for topic in topics])

# Display the first few rows of the new DataFrame
reviews_with_topics_custom
# Out:
#                                                  Review Top_3_Topics  \
# 0     The ambience was good, food was quite good. ha...    [3, 0, 9]
# 1     Ambience is too good for a pleasant evening. S...    [3, 0, 9]
# 2     A must try.. great food great ambience. Thnx f...    [3, 0, 9]
# 3     Soumen das and Arun was a great guy. Only beca...    [0, 3, 9]
# 4     Food is good. we ordered Kodi drumsticks and b...    [0, 3, 5]
# ...                                                 ...          ...
# 9995  Madhumathi Mahajan Well to start with nice cou...    [5, 6, 9]
# 9996  This place has never disappointed us.. The foo...    [8, 6, 9]
# 9997  Bad rating is mainly because of "Chicken Bone ...    [8, 6, 9]
# 9998  I personally love and prefer Chinese Food. Had...    [8, 6, 9]
# 9999  Checked in here to try some delicious chinese ...    [8, 6, 9]
#
#       Top_3_Probabilities                Topics_MMR  \
# 0     [12.87, 11.6, 5.24]   [place, service, momos]
# 1     [50.38, 5.48, 3.94]   [place, service, momos]
# 2      [20.3, 6.49, 5.25]   [place, service, momos]
# 3      [29.91, 7.12, 4.5]   [service, place, momos]
# 4      [6.73, 6.39, 6.16]  [service, place, buffet]
# ...                   ...                       ...
# 9995  [29.27, 7.66, 5.46]   [buffet, paneer, momos]
# 9996  [50.48, 3.95, 3.11]  [chinese, paneer, momos]
# 9997   [6.12, 3.17, 2.46]  [chinese, paneer, momos]
# 9998  [68.19, 2.97, 2.34]  [chinese, paneer, momos]
# 9999  [19.32, 5.79, 4.49]  [chinese, paneer, momos]
#
#                        Topics_KB
# 0      [hangout, service, momos]
# 1      [hangout, service, momos]
# 2      [hangout, service, momos]
# 3      [service, hangout, momos]
# 4     [service, hangout, buffet]
# ...                          ...
# 9995    [buffet, punjabi, momos]
# 9996   [chinese, punjabi, momos]
# 9997   [chinese, punjabi, momos]
# 9998   [chinese, punjabi, momos]
# 9999   [chinese, punjabi, momos]
#
# [9910 rows x 5 columns]

# %%
model_custom_merged.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2edbd03f-a4e1-4383-bcfd-acfdec6b8a39" class="plotly-graph-div" style="height:590px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2edbd03f-a4e1-4383-bcfd-acfdec6b8a39")) {                    Plotly.newPlot(                        "2edbd03f-a4e1-4383-bcfd-acfdec6b8a39",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["hyderabad_gachibowli_place_best_food","","","place_ambience_music_good_dj"],"x":[0.0,0.3428311136554212,0.3428311136554212,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["hyderabad_gachibowli_place_best_food","","","service_food_staff_manager_experience"],"x":[0.3428311136554212,0.46791206310379563,0.46791206310379563,0.0],"xaxis":"x","y":[-30.0,-30.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["pizza_pasta_cheese_ravioli_italian","","","service_food_staff_manager_experience"],"x":[0.0,0.6511564898400984,0.6511564898400984,0.46791206310379563],"xaxis":"x","y":[-15.0,-15.0,-37.5,-37.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","buffet_chicken_fish_veg_starters"],"x":[0.0,0.4293253523543916,0.4293253523543916,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","chinese_noodles_rice_fried_manchurian"],"x":[0.4293253523543916,0.5964944348941534,0.5964944348941534,0.0],"xaxis":"x","y":[-60.0,-60.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","biryani_chicken_taste_ordered_good"],"x":[0.5964944348941534,0.6291471360781216,0.6291471360781216,0.0],"xaxis":"x","y":[-67.5,-67.5,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","paneer_punjabi_paratha_indian_north"],"x":[0.6291471360781216,0.6447712341481641,0.6447712341481641,0.0],"xaxis":"x","y":[-76.25,-76.25,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","paneer_punjabi_paratha_indian_north"],"x":[0.6511564898400984,0.7467733154354718,0.7467733154354718,0.6447712341481641],"xaxis":"x","y":[-26.25,-26.25,-85.625,-85.625],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["mandi_yum_chicken_arabian_tree","","","paneer_punjabi_paratha_indian_north"],"x":[0.0,0.8879052759144307,0.8879052759144307,0.7467733154354718],"xaxis":"x","y":[-5.0,-5.0,-55.9375,-55.9375],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["momos_haleem_wrap_sizzlers_coffee","","","cake_cakes_chocolate_brownies_cupcakes"],"x":[0.0,0.7171616713948612,0.7171616713948612,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["momos_haleem_wrap_sizzlers_coffee","","","chai_irani_cafe_karachi_old"],"x":[0.7171616713948612,0.8241947959682993,0.8241947959682993,0.0],"xaxis":"x","y":[-120.0,-120.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["pancakes_waffle_tea_waffles_nutella","","","chai_irani_cafe ...

# %%
model_custom_merged.merge_topics(reviews_preproc, topics_to_merge=[[16,23,21,25], [4,3]])

# %%
len(model_custom_merged.get_topic_info())
# Out:
# 23

# %%
model_custom_merged.get_topic_info()
# Out:
#     Topic  Count                               Name  \
# 0      -1   4328         -1_food_good_place_service
# 1       0    947    0_place_ambience_food_hyderabad
# 2       1    823       1_service_food_staff_manager
# 3       2    654          2_delivery_good_nice_fast
# 4       3    601    3_biryani_chicken_taste_ordered
# 5       4    299          4_buffet_chicken_veg_fish
# 6       5    275    5_paneer_punjabi_paratha_indian
# 7       6    260      6_quantity_taste_quality_food
# 8       7    239       7_chinese_noodles_rice_fried
# 9       8    217         8_momos_haleem_wrap_coffee
# 10      9    207             9_ice_cream_shake_chai
# 11     10    201   10_cake_cakes_chocolate_brownies
# 12     11    146   11_shawarma_maggi_chicken_rumali
# 13     12    111    12_zomato_gold_order_restaurant
# 14     13     92  13_veg_vegetarian_non_vegetarians
# 15     14     90   14_burger_burgers_chicken_galaxy
# 16     15     88      15_pizza_pasta_cheese_ravioli
# 17     16     79             16_super_test_good_bad
# 18     17     67        17_chicken_cooked_bad_worst
# 19     18     57   18_donuts_donut_dunkin_chocolate
# 20     19     53       19_mandi_yum_chicken_arabian
# 21     20     41         20_spicy____uncooked_super
# 22     21     35       21_wings_chicken_wild_sauces
#
#                                        Representation  \
# 0   [food, good, place, service, chicken, ambience...
# 1   [place, ambience, food, hyderabad, good, music...
# 2   [service, food, staff, manager, experience, go...
# 3   [delivery, good, nice, fast, order, time, boy,...
# 4   [biryani, chicken, taste, ordered, good, mutto...
# 5   [buffet, chicken, veg, fish, starters, good, m...
# 6   [paneer, punjabi, paratha, indian, north, para...
# 7   [quantity, taste, quality, food, bad, good, wa...
# 8   [chinese, noodles, rice, fried, manchurian, fo...
# 9   [momos, haleem, wrap, coffee, sizzlers, cafe, ...
# 10  [ice, cream, shake, chai, shakes, irani, cream...
# 11  [cake, cakes, chocolate, brownies, cupcakes, v...
# 12  [shawarma, maggi, chicken, rumali, ordered, sh...
# 13  [zomato, gold, order, restaurant, food, servic...
# 14  [veg, vegetarian, non, vegetarians, good, food...
# 15  [burger, burgers, chicken, galaxy, cheese, mil...
# 16  [pizza, pasta, cheese, ravioli, italian, crust...
# 17  [super, test, good, bad, yfjgz, ecpected, ntg,...
# 18  [chicken, cooked, bad, worst, smell, raw, kfc,...
# 19  [donuts, donut, dunkin, chocolate, burger, cof...
# 20  [mandi, yum, chicken, arabian, tree, mutton, b...
# 21  [spicy, __, uncooked, super, stomach, oily, ay...
# 22  [wings, chicken, wild, sauces, nuggets, americ...
#
#                                                   MMR  \
# 0   [food, service, chicken, ambience, experience,...
# 1   [place, ambience, hyderabad, dj, gachibowli, v...
# 2   [service, staff, manager, experience, table, r...
# 3   [delivery, delivered, received, deliver, man, ...
# 4   [biryani, chicken, mutton, biriyani, rice, res...
# 5   [buffet, chicken, lunch, food, desserts, panee...
# 6   [paneer, punjabi, parathas, food, masala, chut...
# 7   [quantity, taste, quality, food, bad, poor, sa...
# 8   [chinese, noodles, rice, manchurian, chicken, ...
# 9   [momos, sizzlers, cafe, kurkure, bikes, wraps,...
# 10  [shakes, irani, creams, tea, chocolate, pancak...
# 11  [cakes, chocolate, brownies, cupcakes, bakery,...
# 12  [shawarma, maggi, chicken, rumali, shah, order...
# 13  [zomato, gold, order, restaurant, delivery, cu...
# 14  [veg, vegetarian, vegetarians, food, restauran...
# 15  [burger, burgers, chicken, milky, grilled, tas...
# 16  [pizza, pasta, ravioli, italian, crust, frio, ...
# 17  [super, test, ntg, gdgd, swipe, decent, expect...
# 18  [chicken, cooked, worst, smell, kfc, rotten, g...
# 19  [donuts, donut, chocolate, burgers, doughnut, ...
# 20  [mandi, arabian, mutton, bbq, rice, seating, f...
# 21  [spicy, uncooked, stomach, oily, ayrup, vegita...
# 22  [chicken, sauces, nuggets, bbq, burger, popcor...
#
#                                               KeyBert  \
# 0   [restaurant, buffet, dishes, food, lunch, dinn...
# 1   [hyderabad, hyderabadi, restaurant, place, pub...
# 2   [service, served, customer, customers, serving...
# 3   [delivery, deliver, delivered, excellent, good...
# 4   [biryani, biryanis, biriyani, briyani, mutton,...
# 5   [buffet, restaurant, dishes, lunch, dish, dinn...
# 6   [punjabi, paneer, meal, punjab, restaurant, pa...
# 7   [quantity, quality, portions, food, value, tas...
# 8   [cuisine, noodles, rice, restaurant, dishes, c...
# 9   [momos, momo, chicken, steamed, rice, tasty, m...
# 10  [icecreams, icecream, ice, cream, flavors, fla...
# 11  [cakes, bakeries, bakery, cake, bakers, cheese...
# 12  [shawarmas, shawarma, shawerma, chicken, mayon...
# 13  [zomato, zomoto, gold, restaurant, golds, cust...
# 14  [buffet, restaurant, tasty, food, veg, serving...
# 15  [burger, burgers, sandwich, meat, hotdog, frie...
# 16  [pizza, restaurant, pizzas, pasta, pastas, foo...
# 17          [super, best, great, awesome, , , , , , ]
# 18  [chicken, cooked, cooking, cook, meat, fried, ...
# 19  [donuts, donut, doughnuts, doughnut, dounuts, ...
# 20  [mandi, mandis, hyderabad, restaurant, food, a...
# 21  [spicy, spices, chilli, tasty, taste, uncooked...
# 22  [wings, chicken, bbq, gachibowli, restaurant, ...
#
#                                                   Pos  \
# 0   [food, good, place, service, chicken, ambience...
# 1   [place, ambience, food, hyderabad, good, music...
# 2   [service, food, staff, manager, experience, go...
# 3   [delivery, good, nice, fast, order, time, boy,...
# 4   [biryani, chicken, taste, good, mutton, biriya...
# 5   [buffet, chicken, veg, fish, starters, good, m...
# 6   [paneer, punjabi, paratha, indian, north, para...
# 7   [quantity, taste, quality, food, bad, good, pr...
# 8   [chinese, noodles, rice, fried, manchurian, fo...
# 9   [momos, haleem, wrap, coffee, sizzlers, cafe, ...
# 10  [ice, cream, shake, chai, shakes, irani, cream...
# 11  [cake, cakes, chocolate, brownies, cupcakes, v...
# 12  [shawarma, maggi, chicken, rumali, shah, doubl...
# 13  [zomato, gold, order, restaurant, food, servic...
# 14  [veg, vegetarian, non, vegetarians, good, food...
# 15  [burger, burgers, chicken, galaxy, cheese, mil...
# 16  [pizza, pasta, cheese, ravioli, italian, crust...
# 17  [super, test, good, bad, yfjgz, delevery, ntg,...
# 18  [chicken, bad, worst, smell, raw, rotten, fres...
# 19  [donuts, donut, dunkin, chocolate, burger, cof...
# 20  [mandi, yum, chicken, arabian, tree, mutton, b...
# 21  [spicy, uncooked, super, stomach, oily, ayrup,...
# 22  [wings, chicken, wild, sauces, nuggets, americ...
#
#                                   Representative_Docs
# 0   [Visited the place on sunday and the place was...
# 1   [One of my favourite place in Hyderabad  Good ...
# 2   [good service, service is good, As the name su...
# 3       [Good delivery, good delivery, good delivery]
# 4   [Paradise Biryani is really good service also ...
# 5   [A go-to place in Gachibowli (especially for T...
# 6   [Awesome North Indian punjabi food served here...
# 7   [quantity less but quality good, Food is not t...
# 8   [As soon you enter the restaurant you get an a...
# 9   [Want to enjoy best steamed momos, this is a m...
# 10  [I ordered death by chocolate ice cream and as...
# 11  [The best tasting and expensive baking place T...
# 12  [One of the best shawarma joints in Hyderabad....
# 13  [Place was fine. And the food was okay. But i ...
# 14  [Restaurant with lot of open place and average...
# 15  [It was bad burger!, burger quality was not go...
# 16  [I was here with my bunch of friends a few day...
# 17                              [super, Super, super]
# 18  [chicken is not cooked well. taste is also not...
# 19  [Was never ever a fan of donuts, untill I tast...
# 20  [Had Delicious juicy mutton margh Mandi. Mutto...
# 21            [very spicy, Was too spicy, very spicy]
# 22  [American Wild Wings = Amazing Wings I happene...

# %%
topics_custom = model_custom_merged.topics_
probs_custom = model_custom_merged.probabilities_

# %%
# Create a DataFrame with reviews and their top 3 assigned topics with probabilities
reviews_with_topics_custom = pd.DataFrame({
    'Review': reviews_preproc,
    'Top_3_Topics': [np.argsort(probs_custom[i])[-3:][::-1] for i in range(len(reviews_preproc))],
    'Top_3_Probabilities': [np.round(np.sort(probs_custom[i])[-3:][::-1] * 100, 2) for i in range(len(reviews_preproc))]
})

# Map the topic IDs to their custom names from topic_aspects_["MMR"]
topic_info_MMR_custom = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_custom_merged.topic_aspects_["MMR"].items()}
topic_info_KB_custom = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_custom_merged.topic_aspects_["KeyBert"].items()}
topic_info_POS_custom = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_custom_merged.topic_aspects_["Pos"].items()}
reviews_with_topics_custom['Topics_MMR'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_MMR_custom[topic] for topic in topics])
reviews_with_topics_custom['Topics_KB'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_KB_custom[topic] for topic in topics])
#reviews_with_topics_custom['Topics_POS'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_POS_custom[topic] for topic in topics])

# Display the first few rows of the new DataFrame
reviews_with_topics_custom
# Out:
#                                                  Review Top_3_Topics  \
# 0     The ambience was good, food was quite good. ha...    [0, 1, 8]
# 1     Ambience is too good for a pleasant evening. S...    [0, 1, 8]
# 2     A must try.. great food great ambience. Thnx f...    [0, 1, 8]
# 3     Soumen das and Arun was a great guy. Only beca...    [1, 0, 8]
# 4     Food is good. we ordered Kodi drumsticks and b...    [0, 1, 4]
# ...                                                 ...          ...
# 9995  Madhumathi Mahajan Well to start with nice cou...    [4, 0, 5]
# 9996  This place has never disappointed us.. The foo...    [7, 5, 0]
# 9997  Bad rating is mainly because of "Chicken Bone ...    [7, 5, 0]
# 9998  I personally love and prefer Chinese Food. Had...    [7, 5, 0]
# 9999  Checked in here to try some delicious chinese ...    [7, 5, 0]
#
#       Top_3_Probabilities                                         Topics_MMR  \
# 0     [14.87, 11.6, 5.24]  [place | ambience | hyderabad, service | staff...
# 1     [51.96, 5.48, 3.94]  [place | ambience | hyderabad, service | staff...
# 2      [22.3, 6.49, 5.25]  [place | ambience | hyderabad, service | staff...
# 3       [29.91, 8.8, 4.5]  [service | staff | manager, place | ambience |...
# 4      [8.96, 6.73, 6.16]  [place | ambience | hyderabad, service | staff...
# ...                   ...                                                ...
# 9995  [29.27, 8.22, 7.66]  [buffet | chicken | lunch, place | ambience | ...
# 9996  [50.48, 3.95, 3.81]  [chinese | noodles | rice, paneer | punjabi | ...
# 9997   [6.12, 3.17, 2.68]  [chinese | noodles | rice, paneer | punjabi | ...
# 9998  [68.19, 2.97, 2.89]  [chinese | noodles | rice, paneer | punjabi | ...
# 9999   [19.32, 5.79, 5.2]  [chinese | noodles | rice, paneer | punjabi | ...
#
#                                               Topics_KB
# 0     [hyderabad | hyderabadi | restaurant, service ...
# 1     [hyderabad | hyderabadi | restaurant, service ...
# 2     [hyderabad | hyderabadi | restaurant, service ...
# 3     [service | served | customer, hyderabad | hyde...
# 4     [hyderabad | hyderabadi | restaurant, service ...
# ...                                                 ...
# 9995  [buffet | restaurant | dishes, hyderabad | hyd...
# 9996  [cuisine | noodles | rice, punjabi | paneer | ...
# 9997  [cuisine | noodles | rice, punjabi | paneer | ...
# 9998  [cuisine | noodles | rice, punjabi | paneer | ...
# 9999  [cuisine | noodles | rice, punjabi | paneer | ...
#
# [9910 rows x 5 columns]

# %%
model_custom_merged.merge_topics(reviews_preproc, topics_to_merge=[[9,10,18], [16,20]])

# %%
model_custom_merged.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f9699276-e3ed-4211-9b33-20b52fd2c9c3" class="plotly-graph-div" style="height:485px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9699276-e3ed-4211-9b33-20b52fd2c9c3")) {                    Plotly.newPlot(                        "f9699276-e3ed-4211-9b33-20b52fd2c9c3",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["cake_cream_chocolate_ice_donuts","","","pizza_pasta_cheese_ravioli_italian"],"x":[0.0,0.6078823776222627,0.6078823776222627,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["momos_haleem_wrap_coffee_sizzlers","","","pizza_pasta_cheese_ravioli_italian"],"x":[0.0,0.6623493131812718,0.6623493131812718,0.6078823776222627],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["buffet_chicken_veg_good_fish","","","place_food_good_ambience_hyderabad"],"x":[0.0,0.3623778380362429,0.3623778380362429,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["buffet_chicken_veg_good_fish","","","service_food_staff_manager_good"],"x":[0.3623778380362429,0.43293448935804923,0.43293448935804923,0.0],"xaxis":"x","y":[-50.0,-50.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","service_food_staff_manager_good"],"x":[0.0,0.5405781358473892,0.5405781358473892,0.43293448935804923],"xaxis":"x","y":[-35.0,-35.0,-57.5,-57.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["biryani_chicken_taste_ordered_good","","","chinese_noodles_rice_fried_manchurian"],"x":[0.0,0.6073063286212849,0.6073063286212849,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["biryani_chicken_taste_ordered_good","","","paneer_punjabi_paratha_indian_north"],"x":[0.6073063286212849,0.6355167427613828,0.6355167427613828,0.0],"xaxis":"x","y":[-80.0,-80.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["biryani_chicken_taste_ordered_good","","","paneer_punjabi_paratha_indian_north"],"x":[0.5405781358473892,0.6599891453609876,0.6599891453609876,0.6355167427613828],"xaxis":"x","y":[-46.25,-46.25,-87.5,-87.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["biryani_chicken_taste_ordered_good","","","paneer_punjabi_paratha_indian_north"],"x":[0.6623493131812718,0.8003848801501207,0.8003848801501207,0.6599891453609876],"xaxis":"x","y":[-12.5,-12.5,-66.875,-66.875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["delivery_good_nice_fast_order","","","zomato_gold_order_restaurant_food"],"x":[0.0,0.806600737669258,0.806600737669258,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["spicy_super_test_good_bad","","","zomato_gold_order_restaurant_food"],"x":[0.0,0.917362478599284,0.917362478599284,0.806600737669258],"xaxis":"x","y":[-105.0,-105.0,-120.0,-120.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["chicken_cooked_bad_worst_smell","","","shawarma_maggi_chicken_rumali_ordered"],"x":[0.0,0.7143588737270219 ...

# %%
topics_custom = model_custom_merged.topics_
probs_custom = model_custom_merged.probabilities_

# %%
# Create a DataFrame with reviews and their top 3 assigned topics with probabilities
reviews_with_topics_custom = pd.DataFrame({
    'Review': reviews_preproc,
    'Top_3_Topics': [np.argsort(probs_custom[i])[-3:][::-1] for i in range(len(reviews_preproc))],
    'Top_3_Probabilities': [np.round(np.sort(probs_custom[i])[-3:][::-1] * 100, 2) for i in range(len(reviews_preproc))]
})

# Map the topic IDs to their custom names from topic_aspects_["MMR"]
topic_info_MMR_custom = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_custom_merged.topic_aspects_["MMR"].items()}
topic_info_KB_custom = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_custom_merged.topic_aspects_["KeyBert"].items()}
topic_info_POS_custom = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_custom_merged.topic_aspects_["Pos"].items()}
reviews_with_topics_custom['Topics_MMR'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_MMR_custom[topic] for topic in topics])
reviews_with_topics_custom['Topics_KB'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_KB_custom[topic] for topic in topics])
#reviews_with_topics_custom['Topics_POS'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_POS_custom[topic] for topic in topics])

# Display the first few rows of the new DataFrame
reviews_with_topics_custom
# Out:
#                                                  Review Top_3_Topics  \
# 0     The ambience was good, food was quite good. ha...    [0, 1, 2]
# 1     Ambience is too good for a pleasant evening. S...    [1, 0, 2]
# 2     A must try.. great food great ambience. Thnx f...    [0, 1, 2]
# 3     Soumen das and Arun was a great guy. Only beca...    [2, 0, 1]
# 4     Food is good. we ordered Kodi drumsticks and b...    [0, 1, 2]
# ...                                                 ...          ...
# 9995  Madhumathi Mahajan Well to start with nice cou...    [0, 1, 2]
# 9996  This place has never disappointed us.. The foo...    [0, 1, 3]
# 9997  Bad rating is mainly because of "Chicken Bone ...    [0, 1, 3]
# 9998  I personally love and prefer Chinese Food. Had...    [0, 1, 3]
# 9999  Checked in here to try some delicious chinese ...    [0, 1, 3]
#
#        Top_3_Probabilities                                         Topics_MMR  \
# 0     [34.63, 14.87, 11.6]  [chicken | biryani | food, place | ambience | ...
# 1     [51.96, 24.97, 5.48]  [place | ambience | hyderabad, chicken | birya...
# 2      [32.72, 22.3, 6.49]  [chicken | biryani | food, place | ambience | ...
# 3       [29.91, 27.3, 8.8]  [service | staff | experience, chicken | birya...
# 4      [43.51, 8.96, 6.73]  [chicken | biryani | food, place | ambience | ...
# ...                    ...                                                ...
# 9995   [75.76, 8.22, 5.39]  [chicken | biryani | food, place | ambience | ...
# 9996   [73.95, 3.81, 2.52]  [chicken | biryani | food, place | ambience | ...
# 9997   [24.57, 2.68, 1.98]  [chicken | biryani | food, place | ambience | ...
# 9998    [85.72, 2.89, 1.9]  [chicken | biryani | food, place | ambience | ...
# 9999    [53.11, 5.2, 3.61]  [chicken | biryani | food, place | ambience | ...
#
#                                               Topics_KB
# 0     [buffet | restaurant | tasty, restaurant | pla...
# 1     [restaurant | place | hangout, buffet | restau...
# 2     [buffet | restaurant | tasty, restaurant | pla...
# 3     [service | served | customer, buffet | restaur...
# 4     [buffet | restaurant | tasty, restaurant | pla...
# ...                                                 ...
# 9995  [buffet | restaurant | tasty, restaurant | pla...
# 9996  [buffet | restaurant | tasty, restaurant | pla...
# 9997  [buffet | restaurant | tasty, restaurant | pla...
# 9998  [buffet | restaurant | tasty, restaurant | pla...
# 9999  [buffet | restaurant | tasty, restaurant | pla...
#
# [9910 rows x 5 columns]

# %%
model_custom_merged.get_topic_info()
# Out:
#     Topic  Count                               Name  \
# 0      -1   4328         -1_food_good_place_service
# 1       0    947         0_place_food_good_ambience
# 2       1    823       1_service_food_staff_manager
# 3       2    654          2_delivery_good_nice_fast
# 4       3    601    3_biryani_chicken_taste_ordered
# 5       4    465         4_cake_cream_chocolate_ice
# 6       5    299          5_buffet_chicken_veg_good
# 7       6    275    6_paneer_punjabi_paratha_indian
# 8       7    260      7_quantity_taste_quality_food
# 9       8    239       8_chinese_noodles_rice_fried
# 10      9    217         9_momos_haleem_wrap_coffee
# 11     10    146   10_shawarma_maggi_chicken_rumali
# 12     11    120           11_spicy_super_test_good
# 13     12    111    12_zomato_gold_order_restaurant
# 14     13     92  13_veg_vegetarian_non_vegetarians
# 15     14     90   14_burger_burgers_chicken_galaxy
# 16     15     88      15_pizza_pasta_cheese_ravioli
# 17     16     67        16_chicken_cooked_bad_worst
# 18     17     53       17_mandi_yum_chicken_arabian
# 19     18     35       18_wings_chicken_wild_sauces
#
#                                        Representation  \
# 0   [food, good, place, service, chicken, ambience...
# 1   [place, food, good, ambience, hyderabad, music...
# 2   [service, food, staff, manager, good, experien...
# 3   [delivery, good, nice, fast, order, time, boy,...
# 4   [biryani, chicken, taste, ordered, good, mutto...
# 5   [cake, cream, chocolate, ice, donuts, shake, c...
# 6   [buffet, chicken, veg, good, fish, starters, m...
# 7   [paneer, punjabi, paratha, indian, north, para...
# 8   [quantity, taste, quality, food, bad, good, wa...
# 9   [chinese, noodles, rice, fried, manchurian, fo...
# 10  [momos, haleem, wrap, coffee, sizzlers, cafe, ...
# 11  [shawarma, maggi, chicken, rumali, ordered, sh...
# 12  [spicy, super, test, good, bad, __, expected, ...
# 13  [zomato, gold, order, restaurant, food, servic...
# 14  [veg, vegetarian, non, vegetarians, good, food...
# 15  [burger, burgers, chicken, galaxy, cheese, mil...
# 16  [pizza, pasta, cheese, ravioli, italian, crust...
# 17  [chicken, cooked, bad, worst, smell, raw, kfc,...
# 18  [mandi, yum, chicken, arabian, tree, mutton, b...
# 19  [wings, chicken, wild, sauces, nuggets, americ...
#
#                                                   MMR  \
# 0   [food, service, chicken, ambience, experience,...
# 1   [place, ambience, hyderabad, dj, gachibowli, v...
# 2   [service, staff, manager, experience, table, r...
# 3   [delivery, delivered, received, deliver, man, ...
# 4   [biryani, chicken, mutton, biriyani, rice, res...
# 5   [chocolate, donuts, shake, cakes, brownies, co...
# 6   [buffet, chicken, food, lunch, soup, paneer, t...
# 7   [paneer, punjabi, paratha, food, masala, chutn...
# 8   [quantity, taste, quality, food, bad, poor, sa...
# 9   [chinese, noodles, rice, manchurian, ordered, ...
# 10  [momos, sizzlers, cafe, kurkure, bikes, wraps,...
# 11  [shawarma, maggi, chicken, rumali, shah, order...
# 12  [spicy, test, bad, uncooked, stomach, oily, ve...
# 13  [zomato, gold, order, restaurant, service, del...
# 14  [veg, vegetarian, vegetarians, food, restauran...
# 15  [burger, burgers, chicken, milky, grilled, tas...
# 16  [pizza, pasta, cheese, ravioli, crust, frio, b...
# 17  [chicken, cooked, worst, smell, kfc, rotten, g...
# 18  [mandi, chicken, arabian, mutton, bbq, rice, s...
# 19  [chicken, sauces, nuggets, bbq, burger, popcor...
#
#                                               KeyBert  \
# 0   [restaurant, buffet, dishes, food, lunch, dinn...
# 1   [hyderabad, hyderabadi, restaurant, place, pub...
# 2   [service, served, customer, customers, serving...
# 3   [delivery, deliver, delivered, excellent, good...
# 4   [biryani, biryanis, biriyani, briyani, mutton,...
# 5   [flavors, chocolate, flavours, bakery, donuts,...
# 6   [buffet, restaurant, dishes, lunch, dish, dinn...
# 7   [punjabi, punjab, paneer, restaurant, meal, hy...
# 8   [quantity, quality, portions, food, taste, val...
# 9   [cuisine, noodles, rice, restaurant, dishes, c...
# 10  [momos, momo, steamed, tasty, rice, chicken, m...
# 11  [shawarmas, shawarma, shawerma, chicken, mayon...
# 12  [spicy, spices, chilli, tasty, taste, tasteles...
# 13  [zomato, zomoto, gold, restaurant, golds, cust...
# 14  [veg, restaurant, buffet, tasty, food, serving...
# 15  [burger, burgers, sandwich, meat, hotdog, frie...
# 16  [pizza, restaurant, pizzas, pasta, pastas, foo...
# 17  [chicken, cooked, cooking, cook, meat, fried, ...
# 18  [mandi, mandis, hyderabad, restaurant, food, s...
# 19  [wings, chicken, bbq, gachibowli, restaurant, ...
#
#                                                   Pos  \
# 0   [food, good, place, service, chicken, ambience...
# 1   [place, food, good, ambience, hyderabad, music...
# 2   [service, food, staff, manager, good, experien...
# 3   [delivery, good, nice, fast, order, time, boy,...
# 4   [biryani, chicken, taste, good, mutton, biriya...
# 5   [cake, cream, chocolate, ice, donuts, cakes, p...
# 6   [buffet, chicken, veg, good, fish, starters, m...
# 7   [paneer, punjabi, paratha, indian, north, para...
# 8   [quantity, taste, quality, food, bad, good, pr...
# 9   [chinese, noodles, rice, fried, manchurian, fo...
# 10  [momos, haleem, wrap, coffee, sizzlers, cafe, ...
# 11  [shawarma, maggi, chicken, rumali, shah, doubl...
# 12  [spicy, super, test, good, bad, uncooked, stom...
# 13  [zomato, gold, order, restaurant, food, servic...
# 14  [veg, vegetarian, non, vegetarians, good, food...
# 15  [burger, burgers, chicken, galaxy, cheese, mil...
# 16  [pizza, pasta, cheese, ravioli, italian, crust...
# 17  [chicken, bad, worst, smell, raw, fresh, rotte...
# 18  [mandi, yum, chicken, arabian, tree, mutton, b...
# 19  [wings, chicken, wild, sauces, nuggets, americ...
#
#                                   Representative_Docs
# 0   [The food was awesome and as was the ambience....
# 1   [One of my favourite place in Hyderabad  Good ...
# 2   [service is good, Good service, As the name su...
# 3       [good delivery, good delivery, Good delivery]
# 4   [Paradise Biryani is really good service also ...
# 5   [This is a small ice cream parlour. It has all...
# 6   [Recently we were invited for a food tasting s...
# 7   [Awesome North Indian punjabi food served here...
# 8   [quantity less but quality good, very less qua...
# 9   [As soon you enter the restaurant you get an a...
# 10  [Every time I am having a good experience with...
# 11  [This place serves the best shawarma at the mo...
# 12  [not so good and it is not so spicy, good and ...
# 13  [Place was fine. And the food was okay. But i ...
# 14  [Restaurant with lot of open place and average...
# 15  [It was bad burger!, burger quality was not go...
# 16  [I was here with my bunch of friends a few day...
# 17  [chicken is not cooked well. taste is also not...
# 18  [Had Delicious juicy mutton margh Mandi. Mutto...
# 19  [American Wild Wings = Amazing Wings I happene...

# %% [markdown]
# ## **END  - FINAL VERSION ABOVE**

# %%
reviews_with_topics_custom.to_csv('reviews_with_topics_custom.csv', index=False)

# %%
model_custom_merged.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="93e19722-7b90-4271-bf69-f6cc02137ba7" class="plotly-graph-div" style="height:485px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93e19722-7b90-4271-bf69-f6cc02137ba7")) {                    Plotly.newPlot(                        "93e19722-7b90-4271-bf69-f6cc02137ba7",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["cake_cream_chocolate_ice_donuts","","","pizza_pasta_cheese_ravioli_italian"],"x":[0.0,0.6078823776222627,0.6078823776222627,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["momos_haleem_wrap_coffee_sizzlers","","","pizza_pasta_cheese_ravioli_italian"],"x":[0.0,0.6623493131812718,0.6623493131812718,0.6078823776222627],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["buffet_chicken_veg_good_fish","","","place_food_good_ambience_hyderabad"],"x":[0.0,0.3623778380362429,0.3623778380362429,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["buffet_chicken_veg_good_fish","","","service_food_staff_manager_good"],"x":[0.3623778380362429,0.43293448935804923,0.43293448935804923,0.0],"xaxis":"x","y":[-50.0,-50.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["veg_vegetarian_non_vegetarians_good","","","service_food_staff_manager_good"],"x":[0.0,0.5405781358473892,0.5405781358473892,0.43293448935804923],"xaxis":"x","y":[-35.0,-35.0,-57.5,-57.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["biryani_chicken_taste_ordered_good","","","chinese_noodles_rice_fried_manchurian"],"x":[0.0,0.6073063286212849,0.6073063286212849,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["biryani_chicken_taste_ordered_good","","","paneer_punjabi_paratha_indian_north"],"x":[0.6073063286212849,0.6355167427613828,0.6355167427613828,0.0],"xaxis":"x","y":[-80.0,-80.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["biryani_chicken_taste_ordered_good","","","paneer_punjabi_paratha_indian_north"],"x":[0.5405781358473892,0.6599891453609876,0.6599891453609876,0.6355167427613828],"xaxis":"x","y":[-46.25,-46.25,-87.5,-87.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["biryani_chicken_taste_ordered_good","","","paneer_punjabi_paratha_indian_north"],"x":[0.6623493131812718,0.8003848801501207,0.8003848801501207,0.6599891453609876],"xaxis":"x","y":[-12.5,-12.5,-66.875,-66.875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["delivery_good_nice_fast_order","","","zomato_gold_order_restaurant_food"],"x":[0.0,0.806600737669258,0.806600737669258,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["spicy_super_test_good_bad","","","zomato_gold_order_restaurant_food"],"x":[0.0,0.917362478599284,0.917362478599284,0.806600737669258],"xaxis":"x","y":[-105.0,-105.0,-120.0,-120.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["chicken_cooked_bad_worst_smell","","","shawarma_maggi_chicken_rumali_ordered"],"x":[0.0,0.7143588737270219 ...

# %%
model_custom_merged.merge_topics(reviews_preproc, topics_to_merge=[[17,18,14,10,16],[6,8,3,5,13,15,4,9]])

# %%
model_custom_merged.get_topic_info()
# Out:
#    Topic  Count                             Name  \
# 0     -1   4328       -1_food_good_place_service
# 1      0   2276     0_biryani_good_chicken_place
# 2      1    947       1_place_good_food_ambience
# 3      2    823        2_service_food_good_staff
# 4      3    654        3_delivery_good_nice_fast
# 5      4    391  4_chicken_shawarma_burger_mandi
# 6      5    260    5_quantity_taste_quality_food
# 7      6    120          6_spicy_super_good_test
# 8      7    111   7_zomato_gold_order_restaurant
#
#                                       Representation  \
# 0  [food, good, place, service, chicken, ambience...
# 1  [biryani, good, chicken, place, food, taste, o...
# 2  [place, good, food, ambience, hyderabad, servi...
# 3  [service, food, good, staff, place, experience...
# 4  [delivery, good, nice, fast, order, time, boy,...
# 5  [chicken, shawarma, burger, mandi, wings, magg...
# 6  [quantity, taste, quality, food, good, bad, pr...
# 7  [spicy, super, good, test, bad, __, expected, ...
# 8  [zomato, gold, order, restaurant, food, servic...
#
#                                                  MMR  \
# 0  [food, service, chicken, ambience, visit, veg,...
# 1  [biryani, chicken, food, rice, paneer, buffet,...
# 2  [place, ambience, hyderabad, visit, dj, gachib...
# 3  [service, staff, experience, manager, table, r...
# 4  [delivery, delivered, received, deliver, man, ...
# 5  [chicken, shawarma, mandi, wings, ordered, bur...
# 6  [quantity, taste, quality, food, bad, poor, sa...
# 7  [spicy, test, bad, uncooked, stomach, oily, ta...
# 8  [zomato, gold, order, restaurant, service, del...
#
#                                              KeyBert  \
# 0  [restaurant, buffet, lunch, food, dishes, visi...
# 1  [buffet, restaurant, dishes, dinner, lunch, fo...
# 2  [hangout, restaurant, place, pub, city, places...
# 3  [service, served, customer, excellent, quality...
# 4  [delivery, deliver, delivered, excellent, good...
# 5  [chicken, wings, bbq, restaurant, gachibowli, ...
# 6  [quantity, quality, portions, value, food, tas...
# 7  [spicy, spices, chilli, tasty, taste, tasteles...
# 8  [zomato, zomoto, gold, restaurant, customers, ...
#
#                                                  Pos  \
# 0  [food, good, place, service, chicken, ambience...
# 1  [biryani, good, chicken, place, food, taste, v...
# 2  [place, good, food, ambience, hyderabad, servi...
# 3  [service, food, good, staff, place, experience...
# 4  [delivery, good, nice, fast, order, time, boy,...
# 5  [chicken, shawarma, burger, mandi, wings, magg...
# 6  [quantity, taste, quality, food, good, bad, pr...
# 7  [spicy, super, good, test, bad, uncooked, food...
# 8  [zomato, gold, order, restaurant, food, servic...
#
#                                  Representative_Docs
# 0  [Experience at Arena E Since it is in SLN Term...
# 1  [Around of us went to this place to have lunch...
# 2  [Had been to this place with friends on Saturd...
# 3      [good service, service is good, good service]
# 4      [good delivery, good delivery, good delivery]
# 5  [American Wild Wings is a very affordable plac...
# 6  [Taste is good, but quantity is very less for ...
# 7  [good but not spicy, not so good and it is not...
# 8  [Place was fine. And the food was okay. But i ...

# %%
topics_custom = model_custom_merged.topics_
probs_custom = model_custom_merged.probabilities_

# %%
# Create a DataFrame with reviews and their top 3 assigned topics with probabilities
reviews_with_topics_custom = pd.DataFrame({
    'Review': reviews_preproc,
    'Top_3_Topics': [np.argsort(probs_custom[i])[-3:][::-1] for i in range(len(reviews_preproc))],
    'Top_3_Probabilities': [np.round(np.sort(probs_custom[i])[-2:][::-1] * 100, 2) for i in range(len(reviews_preproc))]
})

# Map the topic IDs to their custom names from topic_aspects_["MMR"]
topic_info_MMR_custom = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_custom_merged.topic_aspects_["MMR"].items()}
topic_info_KB_custom = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_custom_merged.topic_aspects_["KeyBert"].items()}
topic_info_POS_custom = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_custom_merged.topic_aspects_["Pos"].items()}
reviews_with_topics_custom['Topics_MMR'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_MMR_custom[topic] for topic in topics])
reviews_with_topics_custom['Topics_KB'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_KB_custom[topic] for topic in topics])
reviews_with_topics_custom['Topics_POS'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_POS_custom[topic] for topic in topics])

# Display the first few rows of the new DataFrame
reviews_with_topics_custom
# Out:
#                                                  Review Top_3_Topics  \
# 0     The ambience was good, food was quite good. ha...    [0, 1, 2]
# 1     Ambience is too good for a pleasant evening. S...    [1, 0, 2]
# 2     A must try.. great food great ambience. Thnx f...    [0, 1, 2]
# 3     Soumen das and Arun was a great guy. Only beca...    [2, 0, 1]
# 4     Food is good. we ordered Kodi drumsticks and b...    [0, 1, 2]
# ...                                                 ...          ...
# 9995  Madhumathi Mahajan Well to start with nice cou...    [0, 1, 4]
# 9996  This place has never disappointed us.. The foo...    [0, 4, 1]
# 9997  Bad rating is mainly because of "Chicken Bone ...    [0, 4, 1]
# 9998  I personally love and prefer Chinese Food. Had...    [0, 4, 1]
# 9999  Checked in here to try some delicious chinese ...    [0, 4, 1]
#
#      Top_3_Probabilities                                         Topics_MMR  \
# 0         [27.33, 14.87]  [biryani | chicken | food, place | ambience | ...
# 1         [51.96, 19.36]  [place | ambience | hyderabad, biryani | chick...
# 2          [25.83, 22.3]  [biryani | chicken | food, place | ambience | ...
# 3         [29.91, 21.15]  [service | staff | experience, biryani | chick...
# 4           [34.0, 8.96]  [biryani | chicken | food, place | ambience | ...
# ...                  ...                                                ...
# 9995       [63.78, 8.22]  [biryani | chicken | food, place | ambience | ...
# 9996       [67.07, 4.57]  [biryani | chicken | food, chicken | shawarma ...
# 9997       [19.09, 3.59]  [biryani | chicken | food, chicken | shawarma ...
# 9998        [80.59, 3.4]  [biryani | chicken | food, chicken | shawarma ...
# 9999       [43.15, 6.59]  [biryani | chicken | food, chicken | shawarma ...
#
#                                               Topics_KB  \
# 0     [buffet | restaurant | dishes, hangout | resta...
# 1     [hangout | restaurant | place, buffet | restau...
# 2     [buffet | restaurant | dishes, hangout | resta...
# 3     [service | served | customer, buffet | restaur...
# 4     [buffet | restaurant | dishes, hangout | resta...
# ...                                                 ...
# 9995  [buffet | restaurant | dishes, hangout | resta...
# 9996  [buffet | restaurant | dishes, chicken | wings...
# 9997  [buffet | restaurant | dishes, chicken | wings...
# 9998  [buffet | restaurant | dishes, chicken | wings...
# 9999  [buffet | restaurant | dishes, chicken | wings...
#
#                                              Topics_POS
# 0     [biryani | good | chicken, place | good | food...
# 1     [place | good | food, biryani | good | chicken...
# 2     [biryani | good | chicken, place | good | food...
# 3     [service | food | good, biryani | good | chick...
# 4     [biryani | good | chicken, place | good | food...
# ...                                                 ...
# 9995  [biryani | good | chicken, place | good | food...
# 9996  [biryani | good | chicken, chicken | shawarma ...
# 9997  [biryani | good | chicken, chicken | shawarma ...
# 9998  [biryani | good | chicken, chicken | shawarma ...
# 9999  [biryani | good | chicken, chicken | shawarma ...
#
# [9910 rows x 6 columns]

# %%
model_custom_merged.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="62aaa1f8-e414-4ef0-942e-959b5602f9b0" class="plotly-graph-div" style="height:320px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62aaa1f8-e414-4ef0-942e-959b5602f9b0")) {                    Plotly.newPlot(                        "62aaa1f8-e414-4ef0-942e-959b5602f9b0",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["place_good_food_ambience_hyderabad","","","biryani_good_chicken_place_food"],"x":[0.0,0.28805650457131127,0.28805650457131127,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["service_food_good_staff_place","","","biryani_good_chicken_place_food"],"x":[0.0,0.3835325580027096,0.3835325580027096,0.28805650457131127],"xaxis":"x","y":[-15.0,-15.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["service_food_good_staff_place","","","chicken_shawarma_burger_mandi_wings"],"x":[0.3835325580027096,0.606836427661163,0.606836427661163,0.0],"xaxis":"x","y":[-22.5,-22.5,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["zomato_gold_order_restaurant_food","","","chicken_shawarma_burger_mandi_wings"],"x":[0.0,0.7581462916443421,0.7581462916443421,0.606836427661163],"xaxis":"x","y":[-5.0,-5.0,-33.75,-33.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["zomato_gold_order_restaurant_food","","","quantity_taste_quality_food_good"],"x":[0.7581462916443421,0.778984567394613,0.778984567394613,0.0],"xaxis":"x","y":[-19.375,-19.375,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["delivery_good_nice_fast_order","","","spicy_super_good_test_bad"],"x":[0.0,0.7807540816572401,0.7807540816572401,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","text":["delivery_good_nice_fast_order","","","spicy_super_good_test_bad"],"x":[0.778984567394613,1.0531057065880154,1.0531057065880154,0.7807540816572401],"xaxis":"x","y":[-37.1875,-37.1875,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","hovertext":["service_food_good_staff_place","zomato_gold_order_restaurant_food","delivery_good_nice_fast_order"],"marker":{"color":"black"},"mode":"markers","showlegend":false,"x":[0.3835325580027096,0.7581462916443421,0.778984567394613],"y":[-22.5,-19.375,-37.1875],"type":"scatter"},{"hoverinfo":"text","hovertext":["biryani_good_chicken_place_food","chicken_shawarma_burger_mandi_wings","spicy_super_good_test_bad"],"marker":{"color":"black"},"mode":"markers","showlegend":false,"x":[0.28805650457131127,0.606836427661163,0.7807540816572401],"y":[-30.0,-33.75,-70.0],"type":"scatter"}],                        {"autosize":false,"height":320,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["7_zomato_gold_order","2_service_food_good","1_place_good_food","0_biryani_good_chicken","4_chicken_shawarma_burger","5_quantity_taste_quality","3_delivery_good_nice","6_spicy_super_good"],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0,-65.0,-75.0],"type":"linear","zeroline":false,"range":[-80.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color ...

# %%
model_custom_merged.merge_topics(reviews_preproc, topics_to_merge=[[0,5,4,6],[7,3]])

# %%
topics_custom = model_custom_merged.topics_
probs_custom = model_custom_merged.probabilities_

# %%
# Create a DataFrame with reviews and their top 3 assigned topics with probabilities
reviews_with_topics_custom = pd.DataFrame({
    'Review': reviews_preproc,
    'Top_3_Topics': [np.argsort(probs_custom[i])[-3:][::-1] for i in range(len(reviews_preproc))],
    'Top_3_Probabilities': [np.round(np.sort(probs_custom[i])[-2:][::-1] * 100, 2) for i in range(len(reviews_preproc))]
})

# Map the topic IDs to their custom names from topic_aspects_["MMR"]
topic_info_MMR_custom = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_custom_merged.topic_aspects_["MMR"].items()}
topic_info_KB_custom = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_custom_merged.topic_aspects_["KeyBert"].items()}
topic_info_POS_custom = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in model_custom_merged.topic_aspects_["Pos"].items()}
reviews_with_topics_custom['Topics_MMR'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_MMR_custom[topic] for topic in topics])
reviews_with_topics_custom['Topics_KB'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_KB_custom[topic] for topic in topics])
reviews_with_topics_custom['Topics_POS'] = reviews_with_topics_custom['Top_3_Topics'].apply(lambda topics: [topic_info_POS_custom[topic] for topic in topics])

# Display the first few rows of the new DataFrame
reviews_with_topics_custom
# Out:
#                                                  Review Top_3_Topics  \
# 0     The ambience was good, food was quite good. ha...    [0, 1, 2]
# 1     Ambience is too good for a pleasant evening. S...    [1, 0, 2]
# 2     A must try.. great food great ambience. Thnx f...    [0, 1, 2]
# 3     Soumen das and Arun was a great guy. Only beca...    [2, 0, 1]
# 4     Food is good. we ordered Kodi drumsticks and b...    [0, 1, 2]
# ...                                                 ...          ...
# 9995  Madhumathi Mahajan Well to start with nice cou...    [0, 1, 2]
# 9996  This place has never disappointed us.. The foo...    [0, 1, 3]
# 9997  Bad rating is mainly because of "Chicken Bone ...    [0, 1, 3]
# 9998  I personally love and prefer Chinese Food. Had...    [0, 1, 3]
# 9999  Checked in here to try some delicious chinese ...    [0, 1, 3]
#
#      Top_3_Probabilities                                         Topics_MMR  \
# 0         [34.63, 14.87]  [chicken | biryani | food, place | ambience | ...
# 1         [51.96, 24.97]  [place | ambience | hyderabad, chicken | birya...
# 2          [32.72, 22.3]  [chicken | biryani | food, place | ambience | ...
# 3          [29.91, 27.3]  [service | staff | experience, chicken | birya...
# 4          [43.51, 8.96]  [chicken | biryani | food, place | ambience | ...
# ...                  ...                                                ...
# 9995       [75.76, 8.22]  [chicken | biryani | food, place | ambience | ...
# 9996       [73.95, 3.81]  [chicken | biryani | food, place | ambience | ...
# 9997       [24.57, 2.68]  [chicken | biryani | food, place | ambience | ...
# 9998       [85.72, 2.89]  [chicken | biryani | food, place | ambience | ...
# 9999        [53.11, 5.2]  [chicken | biryani | food, place | ambience | ...
#
#                                               Topics_KB  \
# 0     [buffet | restaurant | tasty, restaurant | pla...
# 1     [restaurant | place | hangout, buffet | restau...
# 2     [buffet | restaurant | tasty, restaurant | pla...
# 3     [service | served | customer, buffet | restaur...
# 4     [buffet | restaurant | tasty, restaurant | pla...
# ...                                                 ...
# 9995  [buffet | restaurant | tasty, restaurant | pla...
# 9996  [buffet | restaurant | tasty, restaurant | pla...
# 9997  [buffet | restaurant | tasty, restaurant | pla...
# 9998  [buffet | restaurant | tasty, restaurant | pla...
# 9999  [buffet | restaurant | tasty, restaurant | pla...
#
#                                              Topics_POS
# 0     [good | chicken | biryani, place | good | food...
# 1     [place | good | food, good | chicken | biryani...
# 2     [good | chicken | biryani, place | good | food...
# 3     [service | food | good, good | chicken | birya...
# 4     [good | chicken | biryani, place | good | food...
# ...                                                 ...
# 9995  [good | chicken | biryani, place | good | food...
# 9996  [good | chicken | biryani, place | good | food...
# 9997  [good | chicken | biryani, place | good | food...
# 9998  [good | chicken | biryani, place | good | food...
# 9999  [good | chicken | biryani, place | good | food...
#
# [9910 rows x 6 columns]

# %%
representation_model = model_custom_merged.representation_model

# %%
reviews_with_topics_custom.to_csv('reviews_with_topics_custom(mini).csv', index=False)

# %%
# Modify existing representation models or add new ones
representation_model["MMR"].diversity = 0.5  # Example: Change diversity of MMR

# %%
model_custom_merged.representation_model = representation_model

# %%
# Create a DataFrame with reviews and their top 3 assigned topics with probabilities
reviews_with_topics_custom = pd.DataFrame({
    'Review': reviews_preproc,
    'Top_3_Topics': [np.argsort(probs_custom[i])[-3:][::-1] for i in range(len(reviews_preproc))],
    'Top_3_Probabilities': [np.round(np.sort(probs_custom[i])[-3:][::-1] * 100, 2) for i in range(len(reviews_preproc))]
})

# Map the topic IDs to their custom names from topic_aspects_["MMR"]
#topic_info_MMR_custom = {topic: " | ".join(list(zip(*values))[0][:1]) for topic, values in model_custom_merged.topic_aspects_["MMR"].items()}
topic_info_KB_custom = {topic: " | ".join(list(zip(*values))[0][:1]) for topic, values in model_custom_merged.topic_aspects_["KeyBert"].items()}
#topic_info_POS_custom = {topic: " | ".join(list(zip(*values))[0][:1]) for topic, values in model_custom_merged.topic_aspects_["Pos"].items()}

# Apply the logic to display only the first topic when its probability is 100
def get_topics(row):
    if row['Top_3_Probabilities'][0] == 100:
        return [[topic_info_MMR_custom[row['Top_3_Topics'][0]].split(' | ')[0]], # Get the first word of the topic
                [topic_info_KB_custom[row['Top_3_Topics'][0]].split(' | ')[0]],  # Get the first word of the topic
                [topic_info_POS_custom[row['Top_3_Topics'][0]].split(' | ')[0]]]  # Get the first word of the topic
    else:
        return [[topic_info_MMR_custom[topic] for topic in row['Top_3_Topics']],
                [topic_info_KB_custom[topic] for topic in row['Top_3_Topics']],
                [topic_info_POS_custom[topic] for topic in row['Top_3_Topics']]]

reviews_with_topics_custom[['Topics_MMR', 'Topics_KB', 'Topics_POS']] = reviews_with_topics_custom.apply(get_topics, axis=1, result_type='expand')

# Display the first few rows of the new DataFrame
reviews_with_topics_custom
# Out:
#                                                  Review Top_3_Topics  \
# 0     The ambience was good, food was quite good. ha...    [3, 1, 4]
# 1     Ambience is too good for a pleasant evening. S...    [3, 4, 1]
# 2     A must try.. great food great ambience. Thnx f...    [3, 4, 1]
# 3     Soumen das and Arun was a great guy. Only beca...    [1, 3, 4]
# 4     Food is good. we ordered Kodi drumsticks and b...    [4, 3, 7]
# ...                                                 ...          ...
# 9995  Madhumathi Mahajan Well to start with nice cou...   [13, 0, 6]
# 9996  This place has never disappointed us.. The foo...    [8, 6, 0]
# 9997  Bad rating is mainly because of "Chicken Bone ...    [8, 6, 0]
# 9998  I personally love and prefer Chinese Food. Had...    [8, 6, 0]
# 9999  Checked in here to try some delicious chinese ...    [8, 6, 0]
#
#        Top_3_Probabilities                   Topics_MMR  \
# 0     [12.87, 10.83, 7.23]  [place, service, chocolate]
# 1      [50.38, 5.47, 4.87]  [place, chocolate, service]
# 2       [20.3, 8.08, 5.78]  [place, chocolate, service]
# 3       [29.2, 7.12, 4.72]  [service, place, chocolate]
# 4       [7.28, 6.39, 6.26]   [chocolate, place, buffet]
# ...                    ...                          ...
# 9995   [26.99, 7.84, 7.66]    [chicken, mutton, paneer]
# 9996   [50.48, 3.95, 3.69]    [chinese, paneer, mutton]
# 9997    [6.12, 3.17, 2.83]    [chinese, paneer, mutton]
# 9998   [68.19, 2.97, 2.78]    [chinese, paneer, mutton]
# 9999   [19.32, 5.79, 5.29]    [chinese, paneer, mutton]
#
#                         Topics_KB                  Topics_POS
# 0       [hangout, service, cakes]      [place, service, cake]
# 1       [hangout, cakes, service]      [place, cake, service]
# 2       [hangout, cakes, service]      [place, cake, service]
# 3       [service, hangout, cakes]      [service, place, cake]
# 4        [cakes, hangout, buffet]       [cake, place, buffet]
# ...                           ...                         ...
# 9995   [buffet, biryani, punjabi]  [chicken, biryani, paneer]
# 9996  [noodles, punjabi, biryani]  [chinese, paneer, biryani]
# 9997  [noodles, punjabi, biryani]  [chinese, paneer, biryani]
# 9998  [noodles, punjabi, biryani]  [chinese, paneer, biryani]
# 9999  [noodles, punjabi, biryani]  [chinese, paneer, biryani]
#
# [9910 rows x 6 columns]

# %%
from sentence_transformers import SentenceTransformer

# Pre-calculate embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = embedding_model.encode(reviews_preproc.tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/312 [00:00<?, ?it/s]

# %%
from umap import UMAP

umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine', random_state=42)
from hdbscan import HDBSCAN

hdbscan_model = HDBSCAN(min_cluster_size=30,metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer_model = CountVectorizer(stop_words="english", min_df=2, ngram_range=(1, 2))

# %%
from bertopic.vectorizers import ClassTfidfTransformer

ctfidf_model = ClassTfidfTransformer()

# %%
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance, PartOfSpeech

# KeyBERT
keybert_model = KeyBERTInspired()

# Part-of-Speech
pos_model = PartOfSpeech("en_core_web_sm")

# MMR
mmr_model = MaximalMarginalRelevance(diversity=0.2)

# All representation models
representation_model = {
    "KeyBERT": keybert_model,
    "MMR": mmr_model,
    "POS": pos_model
}

# %%
from bertopic import BERTopic

custom_model = BERTopic(

  # Pipeline models
  embedding_model=embedding_model,
  umap_model=umap_model,
  hdbscan_model=hdbscan_model,
  vectorizer_model=vectorizer_model,
  ctfidf_model=ctfidf_model,
  representation_model=representation_model,

  # Hyperparameters
  top_n_words=10,
  verbose=True
)

topics, probs = custom_model.fit_transform(reviews_preproc, embeddings)
# Out:
# 2024-12-14 17:39:51,547 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-12-14 17:40:08,317 - BERTopic - Dimensionality - Completed ✓
# 2024-12-14 17:40:08,318 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-12-14 17:40:08,762 - BERTopic - Cluster - Completed ✓
# 2024-12-14 17:40:08,766 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-12-14 17:40:35,096 - BERTopic - Representation - Completed ✓

# %%
mrr_topic_labels = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in custom_model.topic_aspects_["MMR"].items()}
custom_model.set_topic_labels(mrr_topic_labels)

# %%
custom_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   4186                 -1_ambience_great_amazing_starters
# 1       0    577  0_biryani_chicken biryani_mutton biryani_biriyani
# 2       1    429                         1_manager_rude_asked_table
# 3       2    332                       2_dj_dance_dance floor_floor
# 4       3    309              3_good good_good_combo good_nice good
# 5       4    231  4_hyderabad_place hyderabad_places hyderabad_h...
# 6       5    226           5_govind_excellent service_excellent_abs
# 7       6    213                    6_zomato_gold_zomato gold_order
# 8       7    192                 7_buffet_spread_hyatt_lunch buffet
# 9       8    166                     8_cake_brownies_cupcakes_cakes
# 10      9    145  9_ambience good_ambience_ambience food_ambienc...
# 11     10    131  10_gachibowli_place gachibowli_located gachibo...
# 12     11    129  11_chinese_chinese food_authentic chinese_chin...
# 13     12    121                          12_fish_prawns_kebab_soup
# 14     13    111              13_vegetarian_non_non veg_vegetarians
# 15     14    108           14_shawarma_chicken shawarma_rumali_shah
# 16     15    104              15_noodles_manchurian_gobi_fried rice
# 17     16    101  16_food tasty_tasty good_awesome food_tasty ex...
# 18     17     97                             17_super_ok_goid_ok ok
# 19     18     95  18_quantity_food quantity_good quantity_food food
# 20     19     93    19_quantity quantity_quantity_sucks_bad quality
# 21     20     89  20_good delivery_delivery_delivery good_delive...
# 22     21     84                 21_ice_cream_ice cream_cream stone
# 23     22     76                   22_burger_burgers_milky_charcoal
# 24     23     70                      23_ravioli_frio_pasta_italian
# 25     24     69                   24_punjabi_dal_lassi_dal makhani
# 26     25     66             25_paratha_parathas_parantha_paranthas
# 27     26     63  26_good service_service good_service thank_tha...
# 28     27     63  27_order delivered_received_wrong order_delivered
# 29     28     62   28_kfc_half cooked_quality chicken_chicken fresh
# 30     29     62                 29_bread_bagel_filter_cream cheese
# 31     30     61           30_indian food_north indian_north_indian
# 32     31     59               31_donuts_donut_dunkin_dunkin donuts
# 33     32     59  32_ordered paneer_paneer_butter masala_paneer ...
# 34     33     58                  33_test good_test_superb_good bad
# 35     34     57                34_momos_momo_steamed_chicken momos
# 36     35     56       35_taste taste_waste_taste waste_worst taste
# 37     36     55  36_time delivery_delivery time_delivery_delive...
# 38     37     54                      37_mandi_arabian_yum_yum tree
# 39     38     53          38_good good_boy good_nice good_good nice
# 40     39     51                      39_shake_shakes_tempteys_oreo
# 41     40     51                          40_bikes_cars_coffee_cafe
# 42     41     49     41_fast delivery_delivery fast_fast_super fast
# 43     42     46  42_place ambience_beautiful ambience_ambience ...
# 44     43     44  43_friends family_staff wonderful_family_think...
# 45     44     41                44_nice nice_nice_person nice_rider
# 46     45     41         45_spicy spicy_spicy_spicy food_spicy good
# 47     46     40  46_food delivered_cold food_plastic_late delivery
# 48     47     39                 47_maggi_maggie_double_egg chicken
# 49     48     38                     48_waffle_waffles_pancakes_tea
# 50     49     37                 49_haleem_pista house_pista_ramzan
# 51     50     37  50_excellent excellent_excellent_awsome_great ...
# 52     51     33            51_andhra_telangana_bamboo chicken_kodi
# 53     52     33                   52_chai_irani_irani chai_karachi
# 54     53     32     53_sizzlers_absolute sizzlers_sizzler_absolute
# 55     54     31                 54_wings_wild_chicken wings_sauces
#
#                                        Representation  \
# 0   [ambience, great, amazing, starters, really, n...
# 1   [biryani, chicken biryani, mutton biryani, bir...
# 2   [manager, rude, asked, table, pathetic, waiter...
# 3   [dj, dance, dance floor, floor, hangout, music...
# 4   [good good, good, combo good, nice good, verry...
# 5   [hyderabad, place hyderabad, places hyderabad,...
# 6   [govind, excellent service, excellent, abs, sh...
# 7   [zomato, gold, zomato gold, order, dominos, de...
# 8   [buffet, spread, hyatt, lunch buffet, buffets,...
# 9   [cake, brownies, cupcakes, cakes, red velvet, ...
# 10  [ambience good, ambience, ambience food, ambie...
# 11  [gachibowli, place gachibowli, located gachibo...
# 12  [chinese, chinese food, authentic chinese, chi...
# 13  [fish, prawns, kebab, soup, virgin, mocktails,...
# 14  [vegetarian, non, non veg, vegetarians, veg, v...
# 15  [shawarma, chicken shawarma, rumali, shah, sha...
# 16  [noodles, manchurian, gobi, fried rice, manchu...
# 17  [food tasty, tasty good, awesome food, tasty e...
# 18  [super, ok, goid, ok ok, nom, excelent, yuck, ...
# 19  [quantity, food quantity, good quantity, food ...
# 20  [quantity quantity, quantity, sucks, bad quali...
# 21  [good delivery, delivery, delivery good, deliv...
# 22  [ice, cream, ice cream, cream stone, ice cream...
# 23  [burger, burgers, milky, charcoal, cosmic, bes...
# 24  [ravioli, frio, pasta, italian, pizza, spinach...
# 25  [punjabi, dal, lassi, dal makhani, makhani, da...
# 26  [paratha, parathas, parantha, paranthas, aloo,...
# 27  [good service, service good, service thank, th...
# 28  [order delivered, received, wrong order, deliv...
# 29  [kfc, half cooked, quality chicken, chicken fr...
# 30  [bread, bagel, filter, cream cheese, croissant...
# 31  [indian food, north indian, north, indian, sou...
# 32  [donuts, donut, dunkin, dunkin donuts, doughnu...
# 33  [ordered paneer, paneer, butter masala, paneer...
# 34  [test good, test, superb, good bad, good good,...
# 35  [momos, momo, steamed, chicken momos, mayo, st...
# 36  [taste taste, waste, taste waste, worst taste,...
# 37  [time delivery, delivery time, delivery, deliv...
# 38  [mandi, arabian, yum, yum tree, yum yum, tree,...
# 39  [good good, boy good, nice good, good nice, bo...
# 40  [shake, shakes, tempteys, oreo, brownie, cherr...
# 41  [bikes, cars, coffee, cafe, bike, rent, driven...
# 42  [fast delivery, delivery fast, fast, super fas...
# 43  [place ambience, beautiful ambience, ambience ...
# 44  [friends family, staff wonderful, family, thin...
# 45  [nice nice, nice, person nice, rider, person, ...
# 46  [spicy spicy, spicy, spicy food, spicy good, t...
# 47  [food delivered, cold food, plastic, late deli...
# 48  [maggi, maggie, double, egg chicken, fried mag...
# 49  [waffle, waffles, pancakes, tea, maple, maple ...
# 50  [haleem, pista house, pista, ramzan, cloves, g...
# 51  [excellent excellent, excellent, awsome, great...
# 52  [andhra, telangana, bamboo chicken, kodi, pula...
# 53  [chai, irani, irani chai, karachi, biscuits, o...
# 54  [sizzlers, absolute sizzlers, sizzler, absolut...
# 55  [wings, wild, chicken wings, sauces, nuggets, ...
#
#                                               KeyBERT  \
# 0   [chicken tikka, restaurant, good food, dishes,...
# 1   [biryani tasty, biryani food, hyderabadi birya...
# 2   [serving, waiters, waiter, serve, service bad,...
# 3   [place party, places hangout, place amazing, f...
# 4   [good, good good, nice good, good nice, nice, ...
# 5   [hyderabadi cuisine, restaurants hyderabad, hy...
# 6   [excellent food, food excellent, good hospital...
# 7   [zomato restaurant, restaurant zomato, food zo...
# 8   [buffet food, buffet menu, dinner buffet, plac...
# 9   [chocolate cake, bakery items, bakery products...
# 10  [food ambience, ambience food, ambience good, ...
# 11  [gachibowli place, visit gachibowli, place gac...
# 12  [chinese cuisine, chinese food, food chinese, ...
# 13  [arabian chicken, chicken soup, chicken, spice...
# 14  [vegetarian dishes, veg dishes, vegetarian foo...
# 15  [chicken shawarma, shawarma good, shawarma bes...
# 16  [chinese dish, noodles ordered, noodles taste,...
# 17  [food tasty, tasty food, delicious food, good ...
# 18  [super, service super, awesome, item, fine, , ...
# 19  [food price, cost food, food quality, taste qu...
# 20  [quality quantity, quantity quality, quantity ...
# 21  [good delivery, great delivery, delivery good,...
# 22  [ice cream, ice creams, chocolate ice, ordered...
# 23  [best burgers, best burger, cosmic burger, bur...
# 24  [italian cuisine, italian food, ravioli pasta,...
# 25  [indian food, food hyderabad, paneer tikka, pu...
# 26  [paneer paratha, ordered paneer, paratha butte...
# 27  [good service, excellent service, service exce...
# 28  [order delivery, deliver order, order delivere...
# 29  [chicken uncooked, chicken tasted, worst chick...
# 30  [visited cafe, cafe, good breads, breakfast, b...
# 31  [indian cuisine, indian food, indian meal, ind...
# 32  [dunkin donuts, donuts good, donuts, good donu...
# 33  [ordered paneer, paneer dish, paneer masala, m...
# 34  [test good, test, good did, good best, good, q...
# 35  [chicken momos, chicken momo, momos, momos pla...
# 36  [taste bad, taste worst, taste waste, taste qu...
# 37  [time delivery, delivery time, late delivery, ...
# 38  [mandi chicken, chicken mandi, fish mandi, jui...
# 39  [boy good, good guy, good good, good, good gre...
# 40  [oreo shake, flavors, milk shakes, taste amazi...
# 41  [driven cafe, cafe, coffee place, cafes, coffe...
# 42  [fast delivery, delivery fast, quick delivery,...
# 43  [ambience place, recommended place, place ambi...
# 44  [tasty place, place visit, food location, plac...
# 45                  [nice, nice nice, , , , , , , , ]
# 46  [food spicy, spicy food, tasty spicy, eat spic...
# 47  [food delivered, delivered food, food delivery...
# 48  [maggi, chicken quality, chicken shawarma, ord...
# 49  [pancakes waffles, waffles, waffle, pancakes, ...
# 50  [haleem, mutton haleem, pista house, desserts ...
# 51  [excellent, excellent excellent, great, amazin...
# 52  [andhra chicken, andhra style, india food, and...
# 53  [karachi cafe, karachi bakery, osmania biscuit...
# 54  [absolute sizzlers, absolute sizzler, best siz...
# 55  [wings chicken, chicken wings, bbq chicken, wi...
#
#                                                   MMR  \
# 0   [ambience, starters, pizza, ambiance, lunch, v...
# 1   [chicken biryani, mutton biryani, biryani good...
# 2   [rude, waiter, customer, worst service, waiter...
# 3   [dance, dance floor, hangout, place hangout, p...
# 4   [good good, good, combo good, nice good, verry...
# 5   [place hyderabad, places hyderabad, hyderabad ...
# 6   [suraj, food excellent, visit soon, service go...
# 7   [zomato, zomato gold, order, dominos, refund, ...
# 8   [buffet, lunch buffet, buffets, buffet spread,...
# 9   [brownies, cupcakes, cakes, cookies, chocolate...
# 10  [ambience good, ambience, ambience food, ambie...
# 11  [place gachibowli, located gachibowli, gachibo...
# 12  [chinese food, authentic chinese, chinese cuis...
# 13  [prawns, kebab, soup, mocktails, crispy, dish,...
# 14  [non veg, veg food, non vegetarian, vegetarian...
# 15  [shawarma, chicken shawarma, shawarmas, mayonn...
# 16  [noodles, fried rice, manchuria, veg fried, ve...
# 17  [food tasty, tasty good, delicious tasty, food...
# 18  [super, goid, yuck, service super, nom nom, ex...
# 19  [food quantity, food food, quantity food, food...
# 20  [quantity quantity, quantity, quantity price, ...
# 21  [good delivery, delivery good, delivery delive...
# 22  [ice cream, cream stone, ice creams, creams, c...
# 23  [burgers, best burgers, best burger, burger pl...
# 24  [ravioli, italian food, penne pasta, pastas, a...
# 25  [punjabi, dal makhani, dal makhni, punjab, kul...
# 26  [paratha, parathas, parantha, paneer paratha, ...
# 27  [good service, service good, service thank, se...
# 28  [order delivered, wrong order, received order,...
# 29  [kfc, quality chicken, chicken fresh, worst fo...
# 30  [bagel, breads, filter coffee, croissants, bag...
# 31  [indian food, north indian, south indian, indi...
# 32  [donuts, dunkin donuts, doughnut, doughnuts, b...
# 33  [ordered paneer, paneer butter, paneer tikka, ...
# 34  [test good, test, good double, expected good, ...
# 35  [momos, steamed, chicken momos, mayo, mayonnai...
# 36  [taste taste, taste waste, worst taste, taste ...
# 37  [time delivery, delivery time, delivery delive...
# 38  [arabian, yum tree, mandi chicken, juicy mandi...
# 39  [boy good, rider, good guy, kind good, good fa...
# 40  [tempteys, milk shake, choco brownie, cookie, ...
# 41  [bikes, cafe, rent, driven cafe, bikes cars, c...
# 42  [fast delivery, delivery fast, delivery super,...
# 43  [place ambience, beautiful ambience, ambience ...
# 44  [friends family, place food, place family, pla...
# 45  [nice nice, nice, person nice, rider, person, ...
# 46  [spicy spicy, spicy food, spicy good, taste sp...
# 47  [food delivered, cold food, late delivery, pac...
# 48  [maggi, maggie, egg chicken, fried maggie, ord...
# 49  [waffle, waffles, pancakes, scrambled, pancake...
# 50  [pista house, shah ghouse, mutton haleem, food...
# 51  [excellent excellent, excellent, awsome, great...
# 52  [andhra, bamboo chicken, ulavacharu, andhra ch...
# 53  [irani, irani chai, biscuits, osmania biscuits...
# 54  [sizzlers, absolute sizzlers, sizzler, absolut...
# 55  [chicken wings, sauces, wild wings, chicken nu...
#
#                                                   POS  \
# 0   [ambience, great, amazing, starters, nice, fri...
# 1   [biryani, biriyani, biryanis, mutton, good bir...
# 2   [manager, rude, table, pathetic, waiter, worst...
# 3   [dj, dance, floor, hangout, music, rooftop, pa...
# 4                   [good, combo, nice, , , , , , , ]
# 5   [hyderabad, hyderabadi, beer, beers, places, b...
# 6   [excellent service, excellent, abs, suraj, exc...
# 7   [zomato, gold, order, dominos, support, contac...
# 8   [buffet, spread, buffets, carte, lunch, good b...
# 9   [cake, brownies, cupcakes, cakes, red velvet, ...
# 10  [ambience, great ambience, average, average fo...
# 11  [gachibowli, area, pax, outlets, places, branc...
# 12  [chinese, chinese food, chinese cuisine, noodl...
# 13  [fish, prawns, soup, mocktails, nawabi, crispy...
# 14  [vegetarian, non, non veg, vegetarians, veg, n...
# 15  [shawarma, rumali, shah, shawarmas, ghouse, ma...
# 16  [noodles, manchurian, gobi, manchuria, rice, b...
# 17  [awesome food, tasty, nice food, delicious foo...
# 18  [super, goid, yuck, excelent, excited, fine, c...
# 19  [quantity, good quantity, salt, bad food, good...
# 20  [quantity, sucks, bad quality, low, poor quali...
# 21  [good delivery, delivery, nice delivery, boy, ...
# 22  [ice, cream, creams, stone, nuts, dry ice, ice...
# 23  [burger, burgers, milky, charcoal, cosmic, bes...
# 24  [ravioli, pasta, italian, pizza, spinach, crus...
# 25  [punjabi, dal, lassi, makhani, makhni, punjab,...
# 26  [paratha, parathas, parantha, paranthas, aloo,...
# 27  [good service, nice service, good patience, go...
# 28  [wrong order, wrong, order, address, incomplet...
# 29  [smell, worst food, worst chicken, rotten, wor...
# 30  [bread, bagel, filter, croissant, sandwich, br...
# 31  [indian food, north, indian, south, good north...
# 32  [donuts, donut, dunkin, doughnut, chocolate, d...
# 33  [paneer, masala, butter, roti, makhani, pannee...
# 34  [test, superb, expectation, bad, plenty, absol...
# 35  [momos, momo, steamed, mayo, mayonnaise, red s...
# 36  [waste, worst taste, bad taste, average taste,...
# 37  [delivery, late delivery, late, time, correct ...
# 38  [mandi, arabian, yum, tree, juicy mandi, grill...
# 39  [boy, rider, good guy, nice, guy, good, fast, ...
# 40  [shake, shakes, oreo, brownie, cherry, caramel...
# 41  [bikes, cars, coffee, cafe, bike, rent, coffee...
# 42  [fast delivery, fast, delivery, speed, faster,...
# 43  [beautiful ambience, space, restraunt, great p...
# 44  [family, faces, nice place, good place, yummy ...
# 45                [nice, rider, person, , , , , , , ]
# 46  [spicy, spicy food, little spicy, uncooked, in...
# 47  [cold food, plastic, late delivery, cutlery, p...
# 48  [maggi, maggie, double, fried maggie, egg, hun...
# 49  [waffle, waffles, pancakes, tea, maple, nutell...
# 50  [haleem, ramzan, ghouse, house, shah, season, ...
# 51          [excellent, great, perfect, , , , , , , ]
# 52  [andhra, kodi, pulav, bamboo, ulavacharu, auth...
# 53  [chai, irani, irani chai, karachi, biscuits, c...
# 54  [sizzlers, absolute sizzlers, sizzler, absolut...
# 55  [wings, wild, sauces, nuggets, wild wings, ama...
#
#                                   Representative_Docs
# 0   ["Oh! Hyderabad" brings amazing super exciting...
# 1   [Another place fo delicious Hyderabadi rum bir...
# 2   [I visited this place with my wife on 16 March...
# 3   [This place has amazing setup, separated in mu...
# 4                             [good, good, good good]
# 5   [So this place is located near ikea above the ...
# 6   [Excellent food and excellent service by bahad...
# 7   [delivery, poor customer support . Both me and...
# 8   [I have had the breakfast buffet here quite a ...
# 9   [A true match for Theo' s from Mumbai, one of ...
# 10  [Ambience- Good for a family dinner . Warm Mel...
# 11  [I was searching for a good Veg place around G...
# 12  [Ohh finally the wait is over, I have been see...
# 13  [Follow my Instagram page Pour House is a spac...
# 14  [Ambience 4 * Food 4 * Staff 4 * Service is a ...
# 15  [One of the besstt places to order shawarma . ...
# 16  [I was craving for some chinese food before ex...
# 17  [food is tasty, good food and tasty, food is t...
# 18                     [super, super delevery, Super]
# 19  [Food is good in terms of taste and the qualit...
# 20  [Quantity is very less, from the last two mont...
# 21  [good delivery, Very good delivery, good deliv...
# 22  [Awesome and wonderful place, I had ordered fr...
# 23  [A hidden treasure, you have to travel across ...
# 24  [This review has been long overdue, I visited ...
# 25  [They definitely promise you a decent meal . K...
# 26  [I have ordered food from this well known para...
# 27  [good service, good service, very good service...
# 28  [In short it was pathetic . They will mark the...
# 29  [Really really bad spring rolls . Smelled real...
# 30  [Whenever I crave to have a good cup of coffee...
# 31  [Situated a little away from the main road Aro...
# 32  [Landed up here on a Saturday night after shop...
# 33  [Ordered the paneer-dal combo for 2 people . I...
# 34       [good test, test is good, test is very good]
# 35  [I ordered the steamed chicken and fried chick...
# 36  [No taste waste of money, did not reach expect...
# 37  [very on time delivery, on time delivery, Bad ...
# 38  [We were 2 friends wanted to eat some mandi .....
# 39             [Good boy, good boy, a very good good]
# 40  [A Sunday afternoon and desserts, definitely m...
# 41  [Love this place from the word go . I always w...
# 42  [super fast delivery, super fast delivery, Sup...
# 43  [I was waiting since long to visit this place ...
# 44  [Place located just opposite of DLF gate no 3,...
# 45                                 [nice, Nice, nice]
# 46  [spicy food upset my stomach also some chicken...
# 47  [Very bad packing of the food . It all got mix...
# 48  [This restaurant is a saviour . This is the an...
# 49  [Kindly try putting more stuffing in the waffl...
# 50  [Ordered Mutton Haleem . It was awesome! Taste...
# 51                  [excellent, excellent, excellent]
# 52  [Had been here to taste authentic andhra/telan...
# 53  [The visit to this place was something on my m...
# 54  [Absolute sizzlers absolutely great place to d...
# 55  [American Wild Wings is another fast food join...

# %%
# Create a DataFrame with reviews and their assigned topics with probabilities, excluding topic -1
topic_info = custom_model.get_topic_info()
reviews_with_topics = pd.DataFrame({
    'Review': reviews_preproc,
    'Assigned_Topic': [topics[i] if topics[i] != -1 else (np.argsort(probs[i])[-2] if len(probs[i]) > 1 else np.argsort(probs[i])[-1]) for i in range(len(reviews_preproc))],
    'Assigned_Topic_Name': [topic_info.iloc[topics[i]]['CustomName'] if topics[i] != -1 else (topic_info.iloc[np.argsort(probs[i])[-2]]['CustomName'] if len(probs[i]) > 1 else topic_info.iloc[np.argsort(probs[i])[-1]]['CustomName']) for i in range(len(reviews_preproc))],
    'Topic_Probabilities': [np.round(probs[i] * 100, 2) if topics[i] != -1 else (np.round(probs[i][np.argsort(probs[i])[-2]] * 100, 2) if len(probs[i]) > 1 else np.round(probs[i][np.argsort(probs[i])[-1]] * 100, 2)) for i in range(len(reviews_preproc))]
}).dropna()

# Display the first few rows of the new DataFrame
reviews_with_topics.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[125], line 5
#       1 # Create a DataFrame with reviews and their assigned topics with probabilities, excluding topic -1
#       2 topic_info = custom_model.get_topic_info()
#       3 reviews_with_topics = pd.DataFrame({
#       4     'Review': reviews_preproc,
# ----> 5     'Assigned_Topic': [topics[i] if topics[i] != -1 else (np.argsort(probs[i])[-2] if len(probs[i]) > 1 else np.argsort(probs[i])[-1]) for i in range(len(reviews_preproc))],
#       6     'Assigned_Topic_Name': [topic_info.iloc[topics[i]]['CustomName'] if topics[i] != -1 else (topic_info.iloc[np.argsort(probs[i])[-2]]['CustomName'] if len(probs[i]) > 1 else topic_info.iloc[np.argsort(probs[i])[-1]]['CustomName']) for i in range(len(reviews_preproc))],
#       7     'Topic_Probabilities': [np.round(probs[i] * 100, 2) if topics[i] != -1 else (np.round(probs[i][np.argsort(probs[i])[-2]] * 100, 2) if len(probs[i]) > 1 else np.round(probs[i][np.argsort(probs[i])[-1]] * 100, 2)) for i in range(len(reviews_preproc))]
#       8 }).dropna()
#      10 # Display the first few rows of the new DataFrame
#      11 reviews_with_topics.head()
#
# Cell In[125], line 5, in <listcomp>(.0)
#       1 # Create a DataFrame with reviews and their assigned topics with probabilities, excluding topic -1
#       2 topic_info = custom_model.get_topic_info()
#       3 reviews_with_topics = pd.DataFrame({
#       4     'Review': reviews_preproc,
# ----> 5     'Assigned_Topic': [topics[i] if topics[i] != -1 else (np.argsort(probs[i])[-2] if len(probs[i]) > 1 else np.argsort(probs[i])[-1]) for i in range(len(reviews_preproc))],
#       6     'Assigned_Topic_Name': [topic_info.iloc[topics[i]]['CustomName'] if topics[i] != -1 else (topic_info.iloc[np.argsort(probs[i])[-2]]['CustomName'] if len(probs[i]) > 1 else topic_info.iloc[np.argsort(probs[i])[-1]]['CustomName']) for i in range(len(reviews_preproc))],
#       7     'Topic_Probabilities': [np.round(probs[i] * 100, 2) if topics[i] != -1 else (np.round(probs[i][np.argsort(probs[i])[-2]] * 100, 2) if len(probs[i]) > 1 else np.round(probs[i][np.argsort(probs[i])[-1]] * 100, 2)) for i in range(len(reviews_preproc))]
#       8 }).dropna()
#      10 # Display the first few rows of the new DataFrame
#      11 reviews_with_topics.head()
#
# TypeError: object of type 'numpy.float64' has no len()

# %%
# Out:
#     Topic  Count                                               Name  \
# 0      -1   3387                         -1_food_chicken_good_place
# 1       0   1753                      0_place_good_ambience_service
# 2       1    561            1_biryani_chicken_chicken biryani_taste
# 3       2    365                      2_manager_service_asked_table
# 4       3    309              3_good good_good_nice good_good combo
# 5       4    233                        4_hyderabad_best_place_food
# 6       5    175                     5_buffet_spread_lunch_starters
# 7       6    169                     6_cake_cakes_brownies_cupcakes
# 8       7    131           7_gachibowli_place_place gachibowli_food
# 9       8    131                  8_quantity_packing_food_food food
# 10      9    129                9_chinese_chinese food_noodles_food
# 11     10    121                      10_veg_non_vegetarian_non veg
# 12     11    109                        11_chicken_fish_soup_prawns
# 13     12    108           12_shawarma_rumali_chicken shawarma_shah
# 14     13    101              13_noodles_manchurian_rice_fried rice
# 15     14     97                      14_super_ok_super super_ok ok
# 16     15     94          15_quantity_quality_quantity quantity_low
# 17     16     91  16_delivery_good delivery_delivery good_delive...
# 18     17     82                  17_ice_cream_ice cream_ice creams
# 19     18     78  18_delivery_delivered_delivered time_time deli...
# 20     19     76                     19_burger_burgers_galaxy_milky
# 21     20     73                      20_pizza_pasta_ravioli_cheese
# 22     21     69             21_paneer_ordered paneer_masala_butter
# 23     22     65                  22_paratha_parathas_parantha_aloo
# 24     23     64                        23_chicken_cooked_worst_kfc
# 25     24     62        24_order_received_delivered_order delivered
# 26     25     62          25_good service_service good_service_good
# 27     26     61           26_indian_north_north indian_indian food
# 28     27     60                   27_donuts_donut_dunkin_chocolate
# 29     28     58                 28_superb_test_test good_good test
# 30     29     57                      29_momos_kurkure_momo_steamed
# 31     30     56                  30_punjabi_punjabi food_dal_lassi
# 32     31     54                       31_mandi_arabian_yum_chicken
# 33     32     54             32_taste_waste_waste taste_taste taste
# 34     33     53          33_good good_nice good_good nice_boy good
# 35     34     52                    34_bread_coffee_sandwich_cheese
# 36     35     51                   35_shake_shakes_tempteys_brownie
# 37     36     50                          36_coffee_cafe_bikes_cars
# 38     37     49       37_fast delivery_fast_delivery_delivery fast
# 39     38     48                 38_maggi_maggie_double_fried maggi
# 40     39     47        39_awesome food_food_nice food_food awesome
# 41     40     43         40_gold_zomato gold_zomato_gold membership
# 42     41     43                 41_zomato_order_support_restaurant
# 43     42     42  42_tasty_delicious tasty_tasty delicious_food ...
# 44     43     41         43_spicy_spicy spicy_spicy food_spicy good
# 45     44     41           44_nice nice_nice_nice rider_person nice
# 46     45     37  45_excellent excellent_excellent_awsome_great ...
# 47     46     37            46_haleem_pista house_pista_haleem good
# 48     47     36                     47_waffle_waffles_tea_pancakes
# 49     48     34          48_andhra_authentic andhra_kodi_authentic
# 50     49     34                 49_wings_chicken wings_wild_sauces
# 51     50     33                   50_chai_irani_irani chai_karachi
# 52     51     32     51_sizzlers_sizzler_absolute_absolute sizzlers
# 53     52     30                   52_wrap_wraps_jumbo_chicken wrap
# 54     53     27  53_awesome awesome_awesome_cool awesome_thank ...
#
#                                            CustomName  \
# 0                         food | chicken | restaurant
# 1                          place | ambience | service
# 2         chicken biryani | biriyani | mutton biryani
# 3                              manager | table | rude
# 4                        good good | good | nice good
# 5                 hyderabad | place hyderabad | visit
# 6                        buffet | lunch | main course
# 7                         cakes | brownies | cupcakes
# 8                gachibowli | place gachibowli | food
# 9                   food food | food good | food cold
# 10                chinese food | noodles | fried rice
# 11                 vegetarian | non veg | vegetarians
# 12                            chicken | soup | prawns
# 13         chicken shawarma | shah ghouse | shawarmas
# 14                      noodles | fried rice | chilli
# 15           super super | super just | super excited
# 16  quantity quantity | service quantity | quality...
# 17   delivery good | delivery boy | delivery delivery
# 18                    ice creams | cream stone | nuts
# 19     delivered time | time delivery | delivery time
# 20                           burger | burgers | milky
# 21                            pizza | pasta | ravioli
# 22            paneer | ordered paneer | butter masala
# 23                       paratha | parathas | chutney
# 24                kfc | half cooked | quality chicken
# 25           order delivered | wrong order | delivery
# 26        good service | service good | service thank
# 27        north indian | indian food | indian cuisine
# 28                   donuts | dunkin donuts | burgers
# 29                test good | good test | good superb
# 30                momos | chicken momos | fried momos
# 31               punjabi | punjabi food | dal makhani
# 32             yum tree | mandi chicken | chicken bbq
# 33            waste taste | taste taste | taste waste
# 34                   boy good | nice rider | good guy
# 35              cream cheese | filter coffee | breads
# 36                 tempteys | caramel brownie | fries
# 37                               coffee | cafe | bike
# 38     fast delivery | delivery fast | delivery super
# 39          fried maggi | double chicken | egg double
# 40            awesome food | food awesome | good food
# 41             zomato gold | zomato | gold membership
# 42                        zomato | faasos | delivered
# 43          tasty delicious | food tasty | tasty food
# 44              spicy spicy | spicy food | spicy good
# 45                      nice nice | nice | nice rider
# 46           excellent excellent | excellent | awsome
# 47                 haleem | pista house | haleem good
# 48           waffles | maple syrup | pancakes waffles
# 49     authentic andhra | bamboo chicken | ulavacharu
# 50                chicken wings | sauces | wild wings
# 51            irani chai | karachi | osmania biscuits
# 52    sizzlers | absolute sizzlers | absolute sizzler
# 53          chicken wrap | jumbo chicken | pizza wrap
# 54           awesome awesome | awesome | cool awesome
#
#                                        Representation  \
# 0   [food, chicken, good, place, ordered, taste, s...
# 1   [place, good, ambience, service, food, great, ...
# 2   [biryani, chicken, chicken biryani, taste, bir...
# 3   [manager, service, asked, table, worst, rude, ...
# 4   [good good, good, nice good, good combo, combo...
# 5   [hyderabad, best, place, food, place hyderabad...
# 6   [buffet, spread, lunch, starters, main, main c...
# 7   [cake, cakes, brownies, cupcakes, chocolate, r...
# 8   [gachibowli, place, place gachibowli, food, go...
# 9   [quantity, packing, food, food food, cold, tas...
# 10  [chinese, chinese food, noodles, food, authent...
# 11  [veg, non, vegetarian, non veg, veg non, veget...
# 12  [chicken, fish, soup, prawns, paneer, dish, se...
# 13  [shawarma, rumali, chicken shawarma, shah, chi...
# 14  [noodles, manchurian, rice, fried rice, fried,...
# 15  [super, ok, super super, ok ok, super just, go...
# 16  [quantity, quality, quantity quantity, low, se...
# 17  [delivery, good delivery, delivery good, deliv...
# 18  [ice, cream, ice cream, ice creams, creams, cr...
# 19  [delivery, delivered, delivered time, time del...
# 20  [burger, burgers, galaxy, milky, chicken, gril...
# 21  [pizza, pasta, ravioli, cheese, frio, italian,...
# 22  [paneer, ordered paneer, masala, butter, butte...
# 23  [paratha, parathas, parantha, aloo, chutney, p...
# 24  [chicken, cooked, worst, kfc, bad, half cooked...
# 25  [order, received, delivered, order delivered, ...
# 26  [good service, service good, service, good, th...
# 27  [indian, north, north indian, indian food, sou...
# 28  [donuts, donut, dunkin, chocolate, coffee, dun...
# 29  [superb, test, test good, good test, good good...
# 30  [momos, kurkure, momo, steamed, chicken momos,...
# 31  [punjabi, punjabi food, dal, lassi, food, makh...
# 32  [mandi, arabian, yum, chicken, mutton, yum yum...
# 33  [taste, waste, waste taste, taste taste, taste...
# 34  [good good, nice good, good nice, boy good, go...
# 35  [bread, coffee, sandwich, cheese, bagel, filte...
# 36  [shake, shakes, tempteys, brownie, caramel, ch...
# 37  [coffee, cafe, bikes, cars, bike, rent, cars b...
# 38  [fast delivery, fast, delivery, delivery fast,...
# 39  [maggi, maggie, double, fried maggi, double eg...
# 40  [awesome food, food, nice food, food awesome, ...
# 41  [gold, zomato gold, zomato, gold membership, m...
# 42  [zomato, order, support, restaurant, deliver, ...
# 43  [tasty, delicious tasty, tasty delicious, food...
# 44  [spicy, spicy spicy, spicy food, spicy good, t...
# 45  [nice nice, nice, nice rider, person nice, rid...
# 46  [excellent excellent, excellent, awsome, great...
# 47  [haleem, pista house, pista, haleem good, hous...
# 48  [waffle, waffles, tea, pancakes, maple, nutell...
# 49  [andhra, authentic andhra, kodi, authentic, pu...
# 50  [wings, chicken wings, wild, sauces, chicken, ...
# 51  [chai, irani, irani chai, karachi, cafe, old, ...
# 52  [sizzlers, sizzler, absolute, absolute sizzler...
# 53  [wrap, wraps, jumbo, chicken wrap, cheese, jum...
# 54  [awesome awesome, awesome, cool awesome, thank...
#
#                                               KeyBERT  \
# 0   [restaurant, buffet, good food, food good, dis...
# 1   [great place, visit place, best place, good pl...
# 2   [chicken biryani, biryani chicken, biryani tas...
# 3   [restaurant, serving, waiters, waiter, lunch, ...
# 4   [good, good good, nice good, good nice, nice, ...
# 5   [hyderabad food, restaurant hyderabad, food hy...
# 6   [buffet food, buffet lunch, dinner buffet, lun...
# 7   [cup cakes, cup cake, cakes, cake chocolate, c...
# 8   [gachibowli place, visit gachibowli, gachibowl...
# 9   [food quality, quality food, taste quality, qu...
# 10  [chinese cuisine, chinese restaurant, chinese ...
# 11  [veg food, veg dishes, place veg, non veg, ord...
# 12  [restaurant, chilli, soup, spices, chicken, bu...
# 13  [shawarma good, chicken shawarma, shawarma chi...
# 14  [ordered noodles, fried noodles, egg noodles, ...
# 15  [super, super super, super just, service super...
# 16  [little quantity, quantity, small quantity, im...
# 17  [good delivery, great delivery, delivery good,...
# 18  [ice cream, ice creams, nuts ice, chocolate ic...
# 19  [delivered time, time delivered, deliver time,...
# 20  [best burgers, best burger, burger good, chick...
# 21  [cheese ravioli, italian food, frio bistro, ra...
# 22  [paneer masala, masala paneer, order paneer, o...
# 23  [paratha delicious, paratha taste, paratha pan...
# 24  [bad chicken, worst chicken, chicken tasted, c...
# 25  [order delivered, ordered delivered, delivered...
# 26  [good service, excellent service, great servic...
# 27  [indian cuisine, indian food, indian meal, ind...
# 28  [chocolate donuts, donuts good, love donuts, d...
# 29  [test good, good test, test, good superb, good...
# 30  [fried momos, chicken momos, momos chicken, mo...
# 31  [punjabi food, punjabi restaurants, punjabi re...
# 32  [bbq mandi, mandi chicken, chicken mandi, mand...
# 33  [taste bad, taste taste, waste taste, taste wa...
# 34  [great good, good good, kind good, good great,...
# 35  [madras baking, good bread, bakery items, bake...
# 36  [brownie shake, taste shake, milk shakes, flav...
# 37  [driven cafe, cafe, cafe good, cafes, coffee p...
# 38  [fast delivery, delivery fast, fastest deliver...
# 39  [chicken maggi, fried maggi, maggi good, chees...
# 40  [awesome food, food awesome, amazing food, gre...
# 41  [zomato gold, gold customers, zomato, using zo...
# 42  [zomato restaurant, zomato customer, service z...
# 43  [tasty, good tasty, delicious tasty, tasty goo...
# 44  [extremely spicy, spicy, super spicy, deliciou...
# 45  [nice, nice nice, nice person, nice rider, , ,...
# 46  [excellent, excellent excellent, excellent gre...
# 47  [taste haleem, best haleem, haleem good, try h...
# 48  [waffles pancakes, pancakes waffles, nutella w...
# 49  [andhra cuisine, andhra dishes, telangana cuis...
# 50  [wings delicious, chicken wings, wings chicken...
# 51  [irani chai, karachi cafe, osmania biscuits, p...
# 52  [sizzlers restaurant, sizzlers great, sizzlers...
# 53  [chicken wrap, wraps, pizza wrap, veg wraps, p...
# 54  [awesome, awesome awesome, cool awesome, aweso...
#
#                                                   MMR  \
# 0   [food, chicken, restaurant, order, rice, panee...
# 1   [place, ambience, service, visit, drinks, frie...
# 2   [chicken biryani, biriyani, mutton biryani, re...
# 3   [manager, table, rude, staff, waiter, customer...
# 4   [good good, good, nice good, good combo, combo...
# 5   [hyderabad, place hyderabad, visit, places, hy...
# 6   [buffet, lunch, main course, lunch buffet, des...
# 7   [cakes, brownies, cupcakes, red velvet, bakery...
# 8   [gachibowli, place gachibowli, food, visit, pl...
# 9   [food food, food good, food cold, quantity foo...
# 10  [chinese food, noodles, fried rice, chinese cu...
# 11  [vegetarian, non veg, vegetarians, main course...
# 12  [chicken, soup, prawns, paneer, dish, main cou...
# 13  [chicken shawarma, shah ghouse, shawarmas, may...
# 14  [noodles, fried rice, chilli, veg fried, chick...
# 15  [super super, super just, super excited, nil, ...
# 16  [quantity quantity, service quantity, quality ...
# 17  [delivery good, delivery boy, delivery deliver...
# 18  [ice creams, cream stone, nuts, chocolate, ice...
# 19  [delivered time, time delivery, delivery time,...
# 20  [burger, burgers, milky, chicken burger, bbq, ...
# 21  [pizza, pasta, ravioli, cheese, crust, frio bi...
# 22  [paneer, ordered paneer, butter masala, paneer...
# 23  [paratha, parathas, chutney, stuffing, paneer ...
# 24  [kfc, half cooked, quality chicken, worst food...
# 25  [order delivered, wrong order, delivery, deliv...
# 26  [good service, service good, service thank, se...
# 27  [north indian, indian food, indian cuisine, in...
# 28  [donuts, dunkin donuts, burgers, doughnuts, ic...
# 29  [test good, good test, good superb, swipe, goo...
# 30  [momos, chicken momos, fried momos, momos good...
# 31  [punjabi, punjabi food, dal makhani, authentic...
# 32  [yum tree, mandi chicken, chicken bbq, arabian...
# 33  [waste taste, taste taste, taste waste, taste ...
# 34  [boy good, nice rider, good guy, fast nice, ri...
# 35  [cream cheese, filter coffee, breads, bakery, ...
# 36  [tempteys, caramel brownie, fries, brownie sha...
# 37  [coffee, cafe, bike, driven cafe, place, bikes...
# 38  [fast delivery, delivery fast, delivery super,...
# 39  [fried maggi, double chicken, egg double, chic...
# 40  [awesome food, food awesome, good food, food n...
# 41  [zomato gold, zomato, gold membership, members...
# 42  [zomato, faasos, delivered, orders, payment, s...
# 43  [tasty delicious, food tasty, tasty food, deli...
# 44  [spicy spicy, spicy food, spicy good, taste sp...
# 45  [nice nice, nice, nice rider, person nice, rid...
# 46  [excellent excellent, excellent, awsome, great...
# 47  [haleem, pista house, haleem good, try haleem,...
# 48  [waffles, maple syrup, pancakes waffles, ginge...
# 49  [authentic andhra, bamboo chicken, ulavacharu,...
# 50  [chicken wings, sauces, wild wings, original h...
# 51  [irani chai, karachi, osmania biscuits, karach...
# 52  [sizzlers, absolute sizzlers, absolute sizzler...
# 53  [chicken wrap, jumbo chicken, pizza wrap, wrap...
# 54  [awesome awesome, awesome, cool awesome, thank...
#
#                                                   POS  \
# 0   [food, chicken, good, place, taste, service, g...
# 1   [place, good, ambience, service, food, great, ...
# 2   [biryani, chicken, taste, biriyani, mutton, go...
# 3   [manager, service, table, worst, rude, staff, ...
# 4                   [good, combo, nice, , , , , , , ]
# 5   [hyderabad, best, place, food, service, great,...
# 6   [buffet, spread, lunch, starters, main, main c...
# 7   [cake, cakes, brownies, cupcakes, chocolate, r...
# 8   [gachibowli, place, food, good, ambience, best...
# 9   [quantity, packing, food, cold, taste, good qu...
# 10  [chinese, chinese food, noodles, food, authent...
# 11  [veg, non, vegetarian, non veg, vegetarians, g...
# 12  [chicken, fish, soup, prawns, paneer, dish, ma...
# 13  [shawarma, rumali, shah, chicken, ghouse, shaw...
# 14  [noodles, manchurian, rice, fried, veg, gobi, ...
# 15  [super, goid, exlent, yuck, excelent, fine, ex...
# 16  [quantity, quality, low, sucks, bad quality, p...
# 17  [delivery, good delivery, boy, awesome deliver...
# 18  [ice, cream, creams, stone, nuts, chocolate, f...
# 19  [delivery, time, late, late delivery, deliver,...
# 20  [burger, burgers, galaxy, milky, chicken, chee...
# 21  [pizza, pasta, ravioli, cheese, italian, crust...
# 22  [paneer, masala, butter, dal, tikka, roti, mak...
# 23  [paratha, parathas, parantha, aloo, chutney, p...
# 24  [chicken, worst, bad, smell, worst food, oil, ...
# 25  [order, wrong, wrong order, delivery, address,...
# 26  [good service, service, good, nice service, ex...
# 27  [indian, north, indian food, south, food, good...
# 28  [donuts, donut, dunkin, chocolate, coffee, bur...
# 29  [superb, test, good test, good, bad, swipe, fa...
# 30  [momos, kurkure, momo, steamed, sauce, fried, ...
# 31  [punjabi, dal, lassi, food, makhani, authentic...
# 32  [mandi, arabian, yum, chicken, mutton, tree, j...
# 33  [taste, waste, bad waste, bad taste, bad, aver...
# 34  [good, boy, nice, nice rider, rider, good guy,...
# 35  [bread, coffee, sandwich, cheese, bagel, filte...
# 36  [shake, shakes, brownie, caramel, cherry, oreo...
# 37  [coffee, cafe, bikes, cars, bike, rent, place,...
# 38  [fast delivery, fast, delivery, super, speed, ...
# 39  [maggi, maggie, double, double egg, double chi...
# 40  [awesome food, food, nice food, good food, awe...
# 41  [gold, zomato, membership, restaurant, service...
# 42  [zomato, order, support, restaurant, customer,...
# 43  [tasty, delicious, tasty food, delicious food,...
# 44  [spicy, spicy food, little spicy, uncooked, su...
# 45     [nice, rider, nice person, person, , , , , , ]
# 46          [excellent, great, perfect, , , , , , , ]
# 47  [haleem, house, ramzan, ghouse, shah, taste, g...
# 48  [waffle, waffles, tea, pancakes, maple, nutell...
# 49  [andhra, authentic andhra, kodi, authentic, pu...
# 50  [wings, wild, sauces, chicken, nuggets, wild w...
# 51  [chai, irani, irani chai, karachi, cafe, old, ...
# 52  [sizzlers, sizzler, absolute, absolute sizzler...
# 53  [wrap, wraps, jumbo, cheese, jumbo chicken, ch...
# 54                    [awesome, cool, , , , , , , , ]
#
#                                   Representative_Docs
# 0   [When you love food and especially north India...
# 1   [Great place to hangout . Good food + Good dri...
# 2   [biryani is good, Just the name of Biryani and...
# 3   [The worst place in the city, I was here for a...
# 4                             [good, good, good good]
# 5   [I am a huge fan of regional cuisines . The di...
# 6   [Very good place to have buffet . Buffet sprea...
# 7   [My boyfriend had gotten a Cheese cake for my ...
# 8   [I love this place in Gachibowli . I have been...
# 9   [Food is not that good . Quantity is more but ...
# 10  [Ohh finally the wait is over, I have been see...
# 11  [Went with team for lunch over first proper pa...
# 12  [Follow my Instagram page Pour House is a spac...
# 13  [horrible shawarma, This place promises to be ...
# 14  [Ordered noodles and fried rice box . Almost n...
# 15  [super delevery, super, I loved it it is just ...
# 16  [less quantity, quantity less, very less quant...
# 17  [good delivery, good delivery, Very good deliv...
# 18  [Delivered only 4 ice Cream, excellent ice cre...
# 19  [he delivered on time, Delivered before the ti...
# 20  [Now that s what we call some authentic chicke...
# 21  [Frio Bistro is located in Gacchibowli, below ...
# 22  [I ordered paneer butter masala and paneer lab...
# 23  [This has become a favourite place to have par...
# 24  [Had a bad experience today in Absolute sizzle...
# 25  [Wrong Order Received, Order not delivered, th...
# 26    [good service, very good service, good service]
# 27  [Bit pricy as compared to the location . Tasty...
# 28  [Had naughty Lucy veg burger meal, alive by ch...
# 29  [not so good test, test is very good, test is ...
# 30  [Its one of my favourite places to have momos ...
# 31  [A decent punjabi food place . Awesome food an...
# 32  [Arabic feel- Ambiance- Yum yum tree is one of...
# 33  [no taste, Very very bad waste taste less do n...
# 34       [very good, very good one, a very good good]
# 35  [Whenever I crave to have a good cup of coffee...
# 36  [We have ordered from this place and it has so...
# 37  [Driven cafe comes with a perfect ambience tha...
# 38  [fast delivery, Fast Delivery, very fast deliv...
# 39  [Who can say no to some delicious Maggi! Hunge...
# 40         [awesome food, awesome food, awesome food]
# 41  [Worst restaurant . They mentioned on Zomato g...
# 42  [Ordered a pizza, garlic bread and other stuff...
# 43               [too tasty it is, very tasty, tasty]
# 44        [very spicy, too spicy, Too much spicy and]
# 45                                 [nice, nice, Nice]
# 46               [excellent, excellent, Excellent!!!]
# 47  [Pista house, known for Haleem in the month of...
# 48  [A sincere request, do not try waffles from he...
# 49  [Food - 4 Ambience - 3 Service - 3 Bamboo Chic...
# 50  [American Wild Wings = Amazing Wings I happene...
# 51  [Visited this place to have Irani chai during ...
# 52  [Absolute sizzlers it is great place to dine G...
# 53  [First things Faasos have always been the firs...
# 54        [Awesome, Awesome, awesome awesome awesome]

# %%
custom_model.visualize_topics()

# %%
custom_model_MRR = custom_model

# %%
# assign labels
keybert_topic_labels = {topic: " | ".join(list(zip(*values))[0][:3]) for topic, values in custom_model.topic_aspects_["KeyBERT"].items()}
custom_model.set_topic_labels(keybert_topic_labels)

# %%
from transformers import pipeline

# Summarization pipeline
summarizer = pipeline("summarization", model="t5-small")

topic_labels = {}
topic_info = custom_model.get_topic_info()

for index, row in topic_info.iterrows():
    topic = row['Topic']
    representative_docs = row['Representation']
    text = " ".join(representative_docs)
    summary = summarizer(text, max_length=2, min_length=1, do_sample=False)
    topic_labels[topic] = summary[0]["summary_text"]

print(topic_labels)
# Out:
# Device set to use cpu
# {-1: 'food', 0: 'place', 1: 'bi', 2: 'manager', 3: 'good', 4: '', 5: 'buffet', 6: 'cake', 7: '', 8: 'quantity', 9: 'authentic', 10: '', 11: 'chicken', 12: '', 13: 'noodles', 14: 'super', 15: 'quantity', 16: 'delivery', 17: '', 18: 'delivery', 19: '', 20: 'pizza', 21: 'pan', 22: 'para', 23: 'chicken', 24: 'order', 25: 'good', 26: 'in', 27: 'mango', 28: 'superb', 29: 'mom', 30: 'pun', 31: 'man', 32: 'taste', 33: 'good', 34: 'bread', 35: 'shake', 36: 'coffee', 37: 'fast', 38: 'ma', 39: 'awesome', 40: 'service', 41: '', 42: 'tasty', 43: 'spicy', 44: 'nice', 45: 'excellent', 46: 'pi', 47: 'wa', 48: 'and', 49: 'wings', 50: '', 51: 'si', 52: 'wrap', 53: 'awesome'}

# %%
custom_model_MRR.get_topic_info().head()
# Out:
#    Topic  Count                                     Name  \
# 0     -1   3387               -1_food_chicken_good_place
# 1      0   1753            0_place_good_ambience_service
# 2      1    561  1_biryani_chicken_chicken biryani_taste
# 3      2    365            2_manager_service_asked_table
# 4      3    309    3_good good_good_nice good_good combo
#
#                                     CustomName  \
# 0                  food | chicken | restaurant
# 1                   place | ambience | service
# 2  chicken biryani | biriyani | mutton biryani
# 3                       manager | table | rude
# 4                 good good | good | nice good
#
#                                       Representation  \
# 0  [food, chicken, good, place, ordered, taste, s...
# 1  [place, good, ambience, service, food, great, ...
# 2  [biryani, chicken, chicken biryani, taste, bir...
# 3  [manager, service, asked, table, worst, rude, ...
# 4  [good good, good, nice good, good combo, combo...
#
#                                              KeyBERT  \
# 0  [restaurant, buffet, good food, food good, dis...
# 1  [great place, visit place, best place, good pl...
# 2  [chicken biryani, biryani chicken, biryani tas...
# 3  [restaurant, serving, waiters, waiter, lunch, ...
# 4  [good, good good, nice good, good nice, nice, ...
#
#                                                  MMR  \
# 0  [food, chicken, restaurant, order, rice, panee...
# 1  [place, ambience, service, visit, drinks, frie...
# 2  [chicken biryani, biriyani, mutton biryani, re...
# 3  [manager, table, rude, staff, waiter, customer...
# 4  [good good, good, nice good, good combo, combo...
#
#                                                  POS  \
# 0  [food, chicken, good, place, taste, service, g...
# 1  [place, good, ambience, service, food, great, ...
# 2  [biryani, chicken, taste, biriyani, mutton, go...
# 3  [manager, service, table, worst, rude, staff, ...
# 4                  [good, combo, nice, , , , , , , ]
#
#                                  Representative_Docs
# 0  [When you love food and especially north India...
# 1  [Great place to hangout . Good food + Good dri...
# 2  [biryani is good, Just the name of Biryani and...
# 3  [The worst place in the city, I was here for a...
# 4                            [good, good, good good]

# %%
custom_model.get_topic_info().head()
# Out:
#    Topic  Count                                     Name  \
# 0     -1   3387               -1_food_chicken_good_place
# 1      0   1753            0_place_good_ambience_service
# 2      1    561  1_biryani_chicken_chicken biryani_taste
# 3      2    365            2_manager_service_asked_table
# 4      3    309    3_good good_good_nice good_good combo
#
#                                     CustomName  \
# 0                  food | chicken | restaurant
# 1                   place | ambience | service
# 2  chicken biryani | biriyani | mutton biryani
# 3                       manager | table | rude
# 4                 good good | good | nice good
#
#                                       Representation  \
# 0  [food, chicken, good, place, ordered, taste, s...
# 1  [place, good, ambience, service, food, great, ...
# 2  [biryani, chicken, chicken biryani, taste, bir...
# 3  [manager, service, asked, table, worst, rude, ...
# 4  [good good, good, nice good, good combo, combo...
#
#                                              KeyBERT  \
# 0  [restaurant, buffet, good food, food good, dis...
# 1  [great place, visit place, best place, good pl...
# 2  [chicken biryani, biryani chicken, biryani tas...
# 3  [restaurant, serving, waiters, waiter, lunch, ...
# 4  [good, good good, nice good, good nice, nice, ...
#
#                                                  MMR  \
# 0  [food, chicken, restaurant, order, rice, panee...
# 1  [place, ambience, service, visit, drinks, frie...
# 2  [chicken biryani, biriyani, mutton biryani, re...
# 3  [manager, table, rude, staff, waiter, customer...
# 4  [good good, good, nice good, good combo, combo...
#
#                                                  POS  \
# 0  [food, chicken, good, place, taste, service, g...
# 1  [place, good, ambience, service, food, great, ...
# 2  [biryani, chicken, taste, biriyani, mutton, go...
# 3  [manager, service, table, worst, rude, staff, ...
# 4                  [good, combo, nice, , , , , , , ]
#
#                                  Representative_Docs
# 0  [When you love food and especially north India...
# 1  [Great place to hangout . Good food + Good dri...
# 2  [biryani is good, Just the name of Biryani and...
# 3  [The worst place in the city, I was here for a...
# 4                            [good, good, good good]

# %%
custom_model_df = pd.DataFrame(custom_model.get_topic_info())
custom_model_mrr_df = pd.DataFrame(custom_model_MRR.get_topic_info())

# %%
merged_df = custom_model_df.join(custom_model_mrr_df, lsuffix='_keybert', rsuffix='_mrr')

# %%
merged_df.head()
# Out:
#    Topic_keybert  Count_keybert  \
# 0             -1           3387
# 1              0           1753
# 2              1            561
# 3              2            365
# 4              3            309
#
#                                      Name_keybert  \
# 0                      -1_food_good_chicken_place
# 1                   0_place_good_ambience_service
# 2         1_biryani_chicken_chicken biryani_taste
# 3                   2_manager_service_asked_table
# 4  3_good good good_good good_good_nice good good
#
#                             CustomName_keybert  \
# 0                    food | chicken | ambience
# 1                   place | ambience | service
# 2  chicken biryani | biriyani | mutton biryani
# 3                      manager | table | worst
# 4  good good good | good good | nice good good
#
#                               Representation_keybert  \
# 0  [food, good, chicken, place, ordered, taste, s...
# 1  [place, good, ambience, service, food, great, ...
# 2  [biryani, chicken, chicken biryani, taste, ord...
# 3  [manager, service, asked, table, worst, rude, ...
# 4  [good good good, good good, good, nice good go...
#
#                                      KeyBERT_keybert  \
# 0  [restaurant, buffet, good food, food good, dis...
# 1  [great place, best place, visit place, good pl...
# 2  [ordered chicken biryani, chicken biryani, bir...
# 3  [restaurant, serving, waiters, waiter, serve, ...
# 4  [good, good good, nice good, good good good, g...
#
#                                          MMR_keybert  \
# 0  [food, chicken, ambience, restaurant, order, r...
# 1  [place, ambience, service, visit, drinks, frie...
# 2  [chicken biryani, biriyani, mutton biryani, re...
# 3  [manager, table, worst, rude, staff, waiter, c...
# 4  [good good good, good good, nice good good, ni...
#
#                                          POS_keybert  \
# 0  [food, good, chicken, place, taste, service, g...
# 1  [place, good, ambience, service, food, great, ...
# 2  [biryani, chicken, taste, biriyani, mutton, go...
# 3  [manager, service, table, worst, rude, staff, ...
# 4                  [good, combo, nice, , , , , , , ]
#
#                          Representative_Docs_keybert  Topic_mrr  Count_mrr  \
# 0  [When you love food and especially north India...         -1       3387
# 1  [Komatose is such wonderful place to chilled o...          0       1753
# 2  [One of the new tastes of biryanis in hyd we o...          1        561
# 3  [Visited this place for my team lunch, and the...          2        365
# 4                            [good, good, good good]          3        309
#
#                                          Name_mrr  \
# 0                      -1_food_good_chicken_place
# 1                   0_place_good_ambience_service
# 2         1_biryani_chicken_chicken biryani_taste
# 3                   2_manager_service_asked_table
# 4  3_good good good_good good_good_nice good good
#
#                                 CustomName_mrr  \
# 0                    food | chicken | ambience
# 1                   place | ambience | service
# 2  chicken biryani | biriyani | mutton biryani
# 3                      manager | table | worst
# 4  good good good | good good | nice good good
#
#                                   Representation_mrr  \
# 0  [food, good, chicken, place, ordered, taste, s...
# 1  [place, good, ambience, service, food, great, ...
# 2  [biryani, chicken, chicken biryani, taste, ord...
# 3  [manager, service, asked, table, worst, rude, ...
# 4  [good good good, good good, good, nice good go...
#
#                                          KeyBERT_mrr  \
# 0  [restaurant, buffet, good food, food good, dis...
# 1  [great place, best place, visit place, good pl...
# 2  [ordered chicken biryani, chicken biryani, bir...
# 3  [restaurant, serving, waiters, waiter, serve, ...
# 4  [good, good good, nice good, good good good, g...
#
#                                              MMR_mrr  \
# 0  [food, chicken, ambience, restaurant, order, r...
# 1  [place, ambience, service, visit, drinks, frie...
# 2  [chicken biryani, biriyani, mutton biryani, re...
# 3  [manager, table, worst, rude, staff, waiter, c...
# 4  [good good good, good good, nice good good, ni...
#
#                                              POS_mrr  \
# 0  [food, good, chicken, place, taste, service, g...
# 1  [place, good, ambience, service, food, great, ...
# 2  [biryani, chicken, taste, biriyani, mutton, go...
# 3  [manager, service, table, worst, rude, staff, ...
# 4                  [good, combo, nice, , , , , , , ]
#
#                              Representative_Docs_mrr
# 0  [When you love food and especially north India...
# 1  [Komatose is such wonderful place to chilled o...
# 2  [One of the new tastes of biryanis in hyd we o...
# 3  [Visited this place for my team lunch, and the...
# 4                            [good, good, good good]

# %%
merged_df = merged_df[['Topic_keybert', 'Count_keybert', 'Name_keybert', 'CustomName_keybert', 'CustomName_mrr','Representation_keybert', 'KeyBERT_keybert','MMR_keybert', 'POS_keybert', 'Representative_Docs_keybert']]
